# %%
from IPython.display import display, HTML
display(HTML('<style>.container { width:80% !important; }</style>'))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime
import matplotlib.pyplot as plt
import math
import urllib.parse

# %%
pd.set_option('display.max_columns', 500) # To utilise larger part of screen

pd.set_option('display.max_colwidth', None) # To show full cell text

# %%
data_path = 'data/cb_20240203'

# %% [markdown]
# # Data Import

# %%
organisations = pd.read_csv(data_path + '/organizations.csv')[['uuid', 'name', 'country_code', 'region', 'city', 'status', 'short_description', 'category_list', 'category_groups_list', 'num_funding_rounds', 'total_funding_usd', 'founded_on', 'logo_url']]
organisations = organisations.rename(columns = {'uuid': 'org_uuid', 'name': 'org_name', 'country_code': 'org_country_code', 'region': 'org_region', 'city': 'org_city', 'logo_url': 'org_logo_url'})

organisations = organisations.assign(founded_on = pd.to_datetime(organisations['founded_on'], errors = 'coerce'))

organisations.head()
# Out:
#                                org_uuid         org_name org_country_code  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd         Wetpaint              USA
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho              USA
# 2  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0             Digg              USA
# 3  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network              USA
# 4  df662812-7f97-0b43-9d3e-12f64f504fbb             Meta              USA
#
#    org_region      org_city     status  \
# 0    New York      New York   acquired
# 1  California    Pleasanton  operating
# 2    New York      New York   acquired
# 3  California  Redwood City  operating
# 4  California    Menlo Park        ipo
#
#                                                                                                                              short_description  \
# 0                                 Wetpaint offers an online social publishing platform that helps digital publishers grow their customer base.
# 1                                                               Zoho offers a suite of business, collaboration, and productivity applications.
# 2  Digg Inc. operates a website that enables its users to find, read, and share the most interesting and talked about stories on the internet.
# 3                                                                                                       Omidyar Network is an investment firm.
# 4                                   Meta is a social technology company that enables people to connect, find communities, and grow businesses.
#
#                                                                                                                                                          category_list  \
# 0                                                                                                                      Publishing,Social Media,Social Media Management
# 1  Cloud Computing,Collaboration,Developer Tools,Enterprise Software,Information Services,Information Technology,Network Security,Project Management,Software,Web Apps
# 2                                                                                                                                 Internet,Social Media,Social Network
# 3                                                                                                               Enterprise Software,Financial Services,Venture Capital
# 4                                                                                     Augmented Reality,Metaverse,Mortgage,Social Media,Social Network,Virtual Reality
#
#                                                                                         category_groups_list  \
# 0                       Content and Publishing,Internet Services,Media and Entertainment,Sales and Marketing
# 1  Administrative Services,Apps,Information Technology,Internet Services,Other,Privacy and Security,Software
# 2                                                                  Internet Services,Media and Entertainment
# 3                                                        Financial Services,Lending and Investments,Software
# 4                                    Hardware,Internet Services,Media and Entertainment,Real Estate,Software
#
#    num_funding_rounds  total_funding_usd founded_on  \
# 0                 3.0       3.975000e+07 2005-06-01
# 1                 NaN                NaN 1996-03-17
# 2                 6.0       4.900000e+07 2004-10-11
# 3                 NaN                NaN 2004-01-01
# 4                14.0       2.460782e+10 2004-02-04
#
#                                                                                                         org_logo_url
# 0  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180177/2036b3394a37152e0ff69f27c71bc883.jpg
# 1  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180181/f8aaab73f17af0296eba5deda7a5b95b.png
# 2  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180182/e77f8f561153ffb45a9ffd538978380d.jpg
# 3              https://images.crunchbase.com/image/upload/t_cb-default-original/v1491524876/tjg7440r2uc0s5neswkp.png
# 4                              https://images.crunchbase.com/image/upload/t_cb-default-original/whm4ed1rrc8skbdi3biv

# %%
people = pd.read_csv(data_path + '/people.csv')[['uuid', 'name', 'country_code', 'region', 'city', 'featured_job_organization_uuid', 'featured_job_title', 'logo_url']]
people = people.rename(columns = {'uuid': 'person_uuid', 'name': 'person_name', 'country_code': 'person_country_code', 'region': 'person_region', 'city': 'person_city', 'featured_job_organization_uuid': 'featured_job_org_uuid', 'logo_url': 'person_logo_url'})

people.head()
# Out:
#                             person_uuid     person_name person_country_code  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71     Ben Elowitz                 USA
# 1  5ceca97b-493c-1446-6249-5aaa33464763  Kevin Flaherty                 USA
# 2  9f99a98a-aa97-b30b-0d36-db67c1d277e0    Raju Vegesna                 USA
# 3  6e1bca72-a865-b518-b305-31214ce2d1b0       Ian Wenig                 NaN
# 4  3b598c59-7b6c-2d48-763c-da55bca77035      Owen Byrne                 USA
#
#   person_region    person_city                 featured_job_org_uuid  \
# 0    Washington        Seattle  1d845b32-7d80-47af-957d-78ccbeeaefb6
# 1    Washington  Mercer Island  789e5e4d-0c90-d06e-92a0-b800b461c3da
# 2    California  San Francisco  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7
# 3           NaN            NaN  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7
# 4    California  Mountain View                                   NaN
#
#         featured_job_title  \
# 0               Co-Founder
# 1              Team Member
# 2         Chief Evangelist
# 3  VP Business Development
# 4                      NaN
#
#                                                                                                      person_logo_url
# 0  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180224/56303d2f4b99dd1dcc8abf17ba3fd8bf.jpg
# 1  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180225/a307ba697e0f042623f05f35477bf495.jpg
# 2                              https://images.crunchbase.com/image/upload/t_cb-default-original/oaxfoww3m0u0lwdovzv3
# 3              https://images.crunchbase.com/image/upload/t_cb-default-original/v1442309935/yiajbpfbxyopc5l4zs4t.png
# 4  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180229/eb6f898475c0bef4c624ed44c9add19a.jpg

# %%
investors = pd.read_csv(data_path + '/investors.csv')[['uuid', 'name', 'roles', 'country_code', 'investor_types', 'investment_count', 'logo_url']]
investors = investors.rename(columns = {'uuid': 'person_uuid', 'name': 'investor_name', 'country_code': 'investor_country_code', 'logo_url': 'investor_logo_url'})

investors.head()
# Out:
#                             person_uuid    investor_name             roles  \
# 0  ed13cd36-fe2b-3707-197b-0c2d56e37a71      Ben Elowitz          investor
# 1  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7             Zoho  investor,company
# 2  f4d5ab44-058b-298b-ea81-380e6e9a8eec  Omidyar Network  investor,company
# 3  df662812-7f97-0b43-9d3e-12f64f504fbb             Meta  investor,company
# 4  a01b8d46-d311-3333-7c34-aa3ae9c03f22  Mark Zuckerberg          investor
#
#   investor_country_code            investor_types  investment_count  \
# 0                   USA                     angel               2.0
# 1                   USA                       NaN               9.0
# 2                   USA  family_investment_office             343.0
# 3                   USA                       NaN              54.0
# 4                   USA  investment_partner,angel               8.0
#
#                                                                                                    investor_logo_url
# 0  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180224/56303d2f4b99dd1dcc8abf17ba3fd8bf.jpg
# 1  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180181/f8aaab73f17af0296eba5deda7a5b95b.png
# 2              https://images.crunchbase.com/image/upload/t_cb-default-original/v1491524876/tjg7440r2uc0s5neswkp.png
# 3                              https://images.crunchbase.com/image/upload/t_cb-default-original/whm4ed1rrc8skbdi3biv
# 4              https://images.crunchbase.com/image/upload/t_cb-default-original/v1448830269/gzcifut4c2xah95x0ewd.jpg

# %%
jobs = pd.read_csv(data_path + '/jobs.csv')[['uuid', 'person_uuid', 'org_uuid', 'started_on', 'ended_on', 'is_current', 'title', 'job_type']]
jobs = jobs.rename(columns = {'uuid': 'job_uuid', 'title': 'job_title'})

jobs = jobs.assign(started_on = pd.to_datetime(jobs['started_on'], errors = 'coerce'))
jobs = jobs.assign(ended_on = pd.to_datetime(jobs['ended_on'], errors = 'coerce'))

jobs = jobs.dropna(subset = ['person_uuid'])

jobs.head()
# Out:
#                                job_uuid                           person_uuid  \
# 0  697b6934-fc1f-9d63-cfb2-1a10759b378e  ed13cd36-fe2b-3707-197b-0c2d56e37a71
# 1  b1de3765-442e-b556-9304-551c2a055901  5ceca97b-493c-1446-6249-5aaa33464763
# 2  1319cd30-f5e8-c700-0af6-64029c6f7124  9f99a98a-aa97-b30b-0d36-db67c1d277e0
# 3  27a252de-1ea8-c620-b2d4-5b889fa9b40f  6e1bca72-a865-b518-b305-31214ce2d1b0
# 4  5a802a79-229f-44ae-0aba-db330f10b67a  c92a1f00-8c19-bf2e-0f28-dbbd383dc968
#
#                                org_uuid started_on   ended_on  is_current  \
# 0  e1393508-30ea-8a36-3f96-dd3226033abd 2005-10-01 2014-06-01       False
# 1  e1393508-30ea-8a36-3f96-dd3226033abd        NaT        NaT       False
# 2  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7 2000-11-01        NaT        True
# 3  bf4d7b0e-b34d-2fd8-d292-6049c4f7efc7 2006-03-01        NaT        True
# 4  5f2b40b8-d1b3-d323-d81a-b7a8e89553d0 2005-07-01 2010-04-05       False
#
#                  job_title   job_type
# 0       Co-Founder and CEO  executive
# 1             VP Marketing  executive
# 2         Chief Evangelist   employee
# 3  VP Business Development  executive
# 4                      CEO  executive

# %%
funding_rounds = pd.read_csv(data_path + '/funding_rounds.csv')[['uuid', 'investment_type', 'announced_on', 'raised_amount_usd', 'org_uuid']]

funding_rounds = funding_rounds.rename(columns = {'uuid': 'funding_round_uuid'})

funding_rounds.head()
# Out:
#                      funding_round_uuid investment_type announced_on  \
# 0  8a945939-18e0-cc9d-27b9-bf33817b2818           angel   2004-09-01
# 1  d950d7a5-79ff-fb93-ca87-13386b0e2feb        series_a   2005-05-01
# 2  6fae3958-a001-27c0-fb7e-666266aedd78        series_b   2006-04-01
# 3  bcd5a63d-ed99-6963-0dd2-e36f6582f846        series_b   2006-05-01
# 4  60e6afd9-1215-465a-dd17-0ed600d4e29b        series_a   2007-01-17
#
#    raised_amount_usd                              org_uuid
# 0           500000.0  df662812-7f97-0b43-9d3e-12f64f504fbb
# 1         12700000.0  df662812-7f97-0b43-9d3e-12f64f504fbb
# 2         27500000.0  df662812-7f97-0b43-9d3e-12f64f504fbb
# 3         10500000.0  f53cb4de-236e-0b1b-dee8-7104a8b018f9
# 4                NaN  4111dc8b-c0df-2d24-ed33-30cd137b3098

# %%
investments = pd.read_csv(data_path + '/investments.csv')[['uuid', 'funding_round_uuid', 'investor_uuid']]

investments = investments.rename(columns = {'uuid': 'investment_uuid'})

investments.head()
# Out:
#                         investment_uuid                    funding_round_uuid  \
# 0  524986f0-3049-54a4-fa72-f60897a5e61d  d950d7a5-79ff-fb93-ca87-13386b0e2feb
# 1  6556ab92-6465-25aa-1ffc-7f8b4b09a476  6fae3958-a001-27c0-fb7e-666266aedd78
# 2  0216e06a-61f8-9cf1-19ba-20811229c53e  6fae3958-a001-27c0-fb7e-666266aedd78
# 3  dadd7d86-520d-5e35-3033-fc1d8792ab91  bcd5a63d-ed99-6963-0dd2-e36f6582f846
# 4  581c4b38-9653-7117-9bd4-7ffe5c7eba69  60e6afd9-1215-465a-dd17-0ed600d4e29b
#
#                           investor_uuid
# 0  b08efc27-da40-505a-6f9d-c9e14247bf36
# 1  e2006571-6b7a-e477-002a-f7014f48a7e3
# 2  8d5c7e48-82da-3025-dd46-346a31bab86f
# 3  7ca12f7a-2f8e-48b4-a8d1-1a33a0e275b9
# 4  fb2f8884-ec07-895a-48d7-d9a9d4d7175c

# %%
investment_partners = pd.read_csv(data_path + '/investment_partners.csv')[['uuid', 'funding_round_uuid', 'partner_uuid']]

investment_partners = investment_partners.rename(columns = {'uuid': 'investment_partner_uuid'})

investment_partners.head()
# Out:
#                 investment_partner_uuid                    funding_round_uuid  \
# 0  524986f0-3049-54a4-fa72-f60897a5e61d  d950d7a5-79ff-fb93-ca87-13386b0e2feb
# 1  524986f0-3049-54a4-fa72-f60897a5e61d  d950d7a5-79ff-fb93-ca87-13386b0e2feb
# 2  6556ab92-6465-25aa-1ffc-7f8b4b09a476  6fae3958-a001-27c0-fb7e-666266aedd78
# 3  0216e06a-61f8-9cf1-19ba-20811229c53e  6fae3958-a001-27c0-fb7e-666266aedd78
# 4  dadd7d86-520d-5e35-3033-fc1d8792ab91  bcd5a63d-ed99-6963-0dd2-e36f6582f846
#
#                            partner_uuid
# 0  2d78d1e7-203c-3eb6-bf1b-c51f10e0679b
# 1  eaf6c243-d355-32f3-e23a-2a5fc82e8b34
# 2  478e7efd-bec4-b9f5-304b-cffedc1fc012
# 3  0f9f3c05-cb79-f58f-6cc5-98ddc8382d4f
# 4  ea9f4980-600c-84f4-a5d6-b4f8c2f787fb

# %%
acquisitions = pd.read_csv(data_path + '/acquisitions.csv')[['acquiree_uuid', 'acquirer_uuid', 'type', 'acquirer_name', 'acquired_on', 'acquisition_type', 'price_usd']]

acquisitions = acquisitions.rename(columns = {'acquiree_uuid': 'org_uuid', 'type': 'exit_type', 'acquired_on': 'exit_date', 'price_usd': 'exit_valuation'})

acquisitions = acquisitions.assign(exit_date = pd.to_datetime(acquisitions['exit_date'], errors = 'coerce'))

acquisitions.head()
# Out:
#                                org_uuid                         acquirer_uuid  \
# 0  180ebf67-68d0-2316-e93d-8e1e546330ba  d70777cc-14bd-2416-0692-5a483781b78b
# 1  5b05e013-a448-3a0b-d872-a6ae668e1192  6acfa7da-1dbd-936e-d985-cf07a1b27711
# 2  8249dffa-1ca6-6f99-9f76-d56c83f85f2d  f09c1228-2e7d-1889-6647-ba5021b2e4ea
# 3  10dd03fa-69ff-3a82-6321-c6b16c9a9f41  6acfa7da-1dbd-936e-d985-cf07a1b27711
# 4  0af10345-613d-e144-f8bd-b62e288985a0  b5a96cd7-044d-70f0-04c5-f125e57a4b35
#
#      exit_type          acquirer_name  exit_date acquisition_type  \
# 0  acquisition  Fox Interactive Media 2007-05-30              NaN
# 1  acquisition                 Google 2007-07-01              NaN
# 2  acquisition      CBS Entertainment 2007-05-01              NaN
# 3  acquisition                 Google 2007-05-23      acquisition
# 4  acquisition       Scripps Networks 2007-07-01              NaN
#
#    exit_valuation
# 0             NaN
# 1      60000000.0
# 2     280000000.0
# 3     100000000.0
# 4             NaN

# %%
ipos = pd.read_csv(data_path + '/ipos.csv')[['org_uuid', 'type', 'went_public_on', 'valuation_price_usd']]

ipos = ipos.rename(columns = {'uuid': 'investment_partner_uuid', 'type': 'exit_type', 'went_public_on': 'exit_date', 'valuation_price_usd': 'exit_valuation'})

ipos = ipos.assign(exit_date = pd.to_datetime(ipos['exit_date'], errors = 'coerce'))

ipos.head()
# Out:
#                                org_uuid exit_type  exit_date  exit_valuation
# 0  fd80725f-53fc-7009-9878-aeecf1e9ffbb       ipo 1986-03-13             NaN
# 1  756936c0-c335-f0ae-0a3d-fe26bdff5695       ipo 1978-01-13             NaN
# 2  73296f0d-85a5-78d5-90b3-86c5f8981ba9       ipo 2006-10-22    1.600000e+08
# 3  ff8439cf-097c-a88a-9bb9-dd83d23aa14b       ipo 1999-12-02             NaN
# 4  ab8e5ba4-df5d-121b-93b6-eae7a0c89245       ipo 1988-08-12    6.000000e+09

# %%
acquisitons_ipos = pd.concat([acquisitions, ipos.drop_duplicates(subset = ['org_uuid', 'exit_date'])], ignore_index = True).sort_values(by = 'exit_date', ascending = False).drop_duplicates(subset = ['org_uuid'])

acquisitons_ipos.head()
# Out:
#                                     org_uuid  \
# 161080  3b46aeb5-9e8b-96ae-eaa0-a7ac254987d9
# 161066  8512ea38-eeec-46c3-a540-020a7e3bd1ae
# 161064  47b41a35-6a1e-494a-98cc-a04692321365
# 211096  14a8cd39-010e-ea26-8afd-513320dd9e3c
# 161059  4af6fb74-d81b-4d9d-8dab-9317d0ab13af
#
#                                acquirer_uuid    exit_type acquirer_name  \
# 161080  d53020f6-8a56-9b9a-764d-bf209256b5b3  acquisition   BAE Systems
# 161066  4bbe63fc-fccb-4b52-981c-5ac694ca63a7  acquisition   Lyvia Group
# 161064  b19fb1ee-c956-8fe9-284b-ce0b1aa02929  acquisition     Indutrade
# 211096                                   NaN          ipo           NaN
# 161059  a621163d-0701-e38d-a9e6-d7778da72eac  acquisition     Bounteous
#
#         exit_date acquisition_type  exit_valuation
# 161080 2024-02-02      acquisition             NaN
# 161066 2024-02-02      acquisition             NaN
# 161064 2024-02-02      acquisition             NaN
# 211096 2024-02-02              NaN             NaN
# 161059 2024-02-01            merge             NaN

# %%
organisations.loc[organisations["org_name"].isin(["Stillfront Group", "MatHem", "Gilion", "DBT", "Juni", "Polarium", "Exeger", "Doktor.se", "Matsmart", "Bambuser", "Foodpanda"])]
# Out:
#                                      org_uuid          org_name  \
# 5489     7b704250-8308-86cf-9a6e-dde320af6f0c          Bambuser
# 49615    31640a8d-c221-dcf9-b9bd-84821a4ca382            Exeger
# 110430   988b8953-a085-8de4-babb-fae5bb895761         Foodpanda
# 302051   58ddd554-5c31-d8fb-895b-863e4b5b7d54            MatHem
# 330310   2d22bf42-6d1f-af3f-ead3-422ba582d440          Matsmart
# 347228   ec788aa9-7351-c263-2109-60c4e7c8e76e          Polarium
# 359975   617ac9c3-1c6b-d675-e545-dc2ae4771e44  Stillfront Group
# 528334   f8f3eb91-f504-4f56-98ab-45d97f439c86         Doktor.se
# 805072   80285077-df2a-4da4-ac5e-00382c1c41c0          Polarium
# 1180214  01595539-a54a-4042-a5d1-98132866bd0c              Juni
# 1667840  4f587a1e-af29-450b-8a70-7baec8cbedac               DBT
# 1790373  b6ae5c8a-bb7d-4b50-84e3-de54f9290e41         Foodpanda
# 3113542  4cf95590-7299-4e2a-8140-81a712a9dce0              Juni
#
#         org_country_code         org_region   org_city     status  \
# 5489                 SWE     Stockholms Lan  Stockholm        ipo
# 49615                SWE     Stockholms Lan  Stockholm  operating
# 110430               DEU             Berlin     Berlin   acquired
# 302051               SWE     Stockholms Lan  Stockholm  operating
# 330310               SWE     Stockholms Lan  Stockholm  operating
# 347228               SWE     Stockholms Lan  Stockholm  operating
# 359975               SWE  Ostergotlands Lan  Linköping        ipo
# 528334               SWE     Stockholms Lan  Stockholm  operating
# 805072               ISR           Tel Aviv   Tel Aviv  operating
# 1180214              SWE    Vastra Gotaland   Göteborg  operating
# 1667840              SWE        Uppsala Lan     Bålsta  operating
# 1790373              THA         Krung Thep    Bangkok  operating
# 3113542              BRA          Sao Paulo  São Paulo  operating
#
#                                                                                                                                  short_description  \
# 5489                                                                                     Bambuser is a SaaS software offering live video shopping.
# 49615                               Exeger develops and commecializes solar cell technology that can absorb light and convert it into electricity.
# 110430      foodpanda is a online food delivery marketplace that enables users to place orders at local restaurants via its website or mobile app.
# 302051      MatHem is an e-commerce company that combines a complete grocery store online with recipes and subscriptions for ready-made groceries.
# 330310   Matsmart sells surplus food and consumer products that would otherwise have been at risk of being thrown away, helping reduce food waste.
# 347228                                                                                      Polarium offers Lithium battery solutions for telecom.
# 359975                                Stillfront Group is an independent games creator and games publisher with a portfolio of high quality games.
# 528334        Doktor.se is a digital healthcare provider that helps with counseling, booking doctors, distance care, recipes, referrals, and more.
# 805072                                                                                 Polarium develops cyber security solutions for enterprises.
# 1180214                      Juni is a fintech company that develops a banking app and platform for e-commerce and online marketing entrepreneurs.
# 1667840                           DBT is a lendtech company providing SMEs with the financing solutions they need to enable innovation and growth.
# 1790373                        Foodpanda is an online food delivery platform that offers pick-up, and delivery services from multiple restaurants.
# 3113542                  Juni is an advertising consultancy specializing in conversion rate optimization and financial tools for digital commerce.
#
#                                                                                    category_list  \
# 5489                                              E-Commerce,SaaS,Software,Video,Video Streaming
# 49615                                                              Energy,Renewable Energy,Solar
# 110430                                             Delivery,E-Commerce,Food Delivery,Marketplace
# 302051                                             E-Commerce,Food and Beverage,Grocery,Internet
# 330310                                                       E-Commerce,Food and Beverage,Retail
# 347228   Battery,Energy,Information Technology,Internet,Mobile,Mobile Devices,Telecommunications
# 359975                                                       Online Games,Publishing,Video Games
# 528334                                                              Health Care,Hospital,Medical
# 805072                                Cyber Security,Enterprise Applications,Enterprise Software
# 1180214                                    Banking,E-Commerce,Finance,Financial Services,FinTech
# 1667840                                                       Banking,Financial Services,FinTech
# 1790373                                   E-Commerce,Food and Beverage,Food Delivery,Restaurants
# 3113542                                                 Advertising,Consulting,Digital Marketing
#
#                                                                          category_groups_list  \
# 5489      Commerce and Shopping,Content and Publishing,Media and Entertainment,Software,Video
# 49615                                                 Energy,Natural Resources,Sustainability
# 110430         Administrative Services,Commerce and Shopping,Food and Beverage,Transportation
# 302051                              Commerce and Shopping,Food and Beverage,Internet Services
# 330310                                                Commerce and Shopping,Food and Beverage
# 347228   Consumer Electronics,Energy,Hardware,Information Technology,Internet Services,Mobile
# 359975                                  Content and Publishing,Gaming,Media and Entertainment
# 528334                                                                            Health Care
# 805072                              Apps,Information Technology,Privacy and Security,Software
# 1180214                      Commerce and Shopping,Financial Services,Lending and Investments
# 1667840                                            Financial Services,Lending and Investments
# 1790373                                Commerce and Shopping,Food and Beverage,Transportation
# 3113542                                 Advertising,Professional Services,Sales and Marketing
#
#          num_funding_rounds  total_funding_usd founded_on  \
# 5489                   16.0        122149152.0 2007-05-01
# 49615                  13.0        224150963.0 2008-01-01
# 110430                  7.0        749450000.0 2012-04-01
# 302051                 13.0        457064253.0 2009-01-01
# 330310                 10.0        142161940.0 2014-01-01
# 347228                  7.0        273891988.0 2015-01-01
# 359975                  7.0        858642434.0 2007-01-01
# 528334                  9.0        189861561.0 2016-01-01
# 805072                  NaN                NaN 2018-02-01
# 1180214                 5.0        281873253.0 2020-01-01
# 1667840                 1.0        285713285.0 2017-01-01
# 1790373                 NaN                NaN 2012-01-01
# 3113542                 NaN                NaN 2018-01-01
#
#                                                                                   org_logo_url
# 5489     https://images.crunchbase.com/image/upload/t_cb-default-original/uoi3fphr5wqsrfxnastp
# 49615    https://images.crunchbase.com/image/upload/t_cb-default-original/uuydwsk52ssfpsthpo7l
# 110430   https://images.crunchbase.com/image/upload/t_cb-default-original/blc2nkqwabrditk9bjyg
# 302051   https://images.crunchbase.com/image/upload/t_cb-default-original/brzbkq4p05rfvrxbcgbx
# 330310   https://images.crunchbase.com/image/upload/t_cb-default-original/pf7lyx83egzn1ph8cbje
# 347228   https://images.crunchbase.com/image/upload/t_cb-default-original/v7fdmt3z1okjjt14gljw
# 359975   https://images.crunchbase.com/image/upload/t_cb-default-original/tkujj8tpqow8ttnct0vd
# 528334   https://images.crunchbase.com/image/upload/t_cb-default-original/e37zgauq9jwtaheavcmg
# 805072   https://images.crunchbase.com/image/upload/t_cb-default-original/d6498b47c83526b985db
# 1180214  https://images.crunchbase.com/image/upload/t_cb-default-original/mabbnmxvz8gsralvcmab
# 1667840  https://images.crunchbase.com/image/upload/t_cb-default-original/gefdkeeojtrjnrgb699x
# 1790373  https://images.crunchbase.com/image/upload/t_cb-default-original/le5eq0qioedrlpjszefq
# 3113542  https://images.crunchbase.com/image/upload/t_cb-default-original/ztq1fa6xqglhmreial16

# %% [markdown]
# # Defining Constants

# %%
# Lowest amount of company funding to consider
funding_cutoff = 100000000

# Company to find alumns for
#target_org_uuid = '96ab87ca-00b5-2ebc-f218-86262954e320' # PayPal
#target_org_uuid = 'df662812-7f97-0b43-9d3e-12f64f504fbb' # Meta
#target_org_uuid = 'a367b036-5952-5435-7541-ad7ee8869e24' # Tesla
target_org_uuid = '022417b5-4980-6c54-0f3c-6736bbbb1a5e' # Spotify
#target_org_uuid = '2cc3a5de-2303-aa00-cd1a-50bd96420392' # Klarna
#target_org_uuid = '34035c51-8f16-4836-8f02-103392479a92' # Northvolt
#target_org_uuid = '7b74b50c-4468-b7ec-2ff9-bf3286a399c9' # Kry
#target_org_uuid = '76e0d11a-3e6b-12b4-7b0b-b4a5a34fba35' # Tink
#target_org_uuid = 'fc4f7ed5-f7c8-34ef-3a8c-42e5d90b4ffb' # Einride
#target_org_uuid = 'd39bb6dc-582d-4878-a224-005497e03766' # Voi
#target_org_uuid = '439d3478-40fa-e6bc-9b71-f1bfa8296f52' # Epidemic Sound
#target_org_uuid = '294302fb-089f-42eb-624a-8ed32494c6b6' # Sinch
#target_org_uuid = '617ac9c3-1c6b-d675-e545-dc2ae4771e44' # Stillfront Group
#target_org_uuid = '71c346d0-0889-486f-aae6-d4463772c13a' # Embracer Group
#target_org_uuid = 'ff4c39cb-f45b-5cdc-36a6-d9111767c351' # Lendify
#target_org_uuid = '6093de34-5382-f34c-a207-efa92470048b' # iZettle
#target_org_uuid = '9a6c8417-c918-40fb-aa7e-bdfd7b4c2273' # Volta Trucks
#target_org_uuid = 'bb6d18e9-fb01-c5d2-d11f-bb24f7eae221' # Storytel
#target_org_uuid = '496cfef9-15f4-d1d7-ea21-b98ce7cdb26c' # Budbee
#target_org_uuid = 'c2c4c27f-f185-49a1-b418-26e258d158db' # Instabox
#target_org_uuid = '6f8f114c-8df6-49de-a301-62242a78efa1' # Anyfin
#target_org_uuid = 'fd80725f-53fc-7009-9878-aeecf1e9ffbb' # Microsoft
#target_org_uuid = '6acfa7da-1dbd-936e-d985-cf07a1b27711' # Google
#target_org_uuid = 'fc5fbe7a-562d-d577-b05e-46797caa134c' # IBM
#target_org_uuid = 'a4f6b817-0b25-d693-1530-de5092f8c827' # Sana
#target_org_uuid = 'eef9eab2-4c50-f0a3-12b8-ce721fa2cc81' # YouTube
#target_org_uuid = 'cc68526b-b2d7-4f7f-cfa7-d93b23716027' # Netscape
#target_org_uuid = '2c23e7ad-4441-5320-fdf9-5aa7007fec0b' # PWC
#target_org_uuid = 'b3a7efa7-e3d3-2d4c-962c-b9fdb1da496f' # Opsware
#target_org_uuid = '1eb37109-3b93-01a9-177f-fee2cb1bfcdc' # Uber
#target_org_uuid = '9a0e860a-7743-28e2-05c0-2b08646d0fe1' # Skype
#target_org_uuid = '988b8953-a085-8de4-babb-fae5bb895761' # Foodpanda
#target_org_uuid = '643d60b4-bfa8-ee61-3316-5af0d8325f33' # Excite

# Years after foundation to consider
years_founding_cutoff = 3

# %%
organisations.loc[organisations['org_name'] == 'Warid Telecom']
# Out:
#                                     org_uuid       org_name org_country_code  \
# 245198  1cbbeafe-03be-8593-f3ac-1dec7918376a  Warid Telecom              PAK
#
#        org_region org_city  status  \
# 245198     Punjab   Lahore  closed
#
#                                                                                                            short_description  \
# 245198  Warid Telecom is a 100% owned company of the Abu Dhabi Group and offers state-of-the-art telecommunication services.
#
#                              category_list category_groups_list  \
# 245198  Mobile,Telecommunications,Wireless      Hardware,Mobile
#
#         num_funding_rounds  total_funding_usd founded_on  \
# 245198                 NaN                NaN 2005-05-01
#
#                                                                                                  org_logo_url
# 245198  https://images.crunchbase.com/image/upload/t_cb-default-original/v1415943316/snnya3ee4fok0yxltwiw.png

# %% [markdown]
# # Creating Main Dataset

# %% [markdown]
# Filter organisations on target name
#
# ## target_org - Information about the target organisation
# Fields:
# - org_uuid
# - org_name
# - org_country_code
# - org_region
# - org_city
# - short_description
# - category_list
# - total_funding_usd
# - founded_on
#
#
# ## alumni_info - Information about target organisation alumnis
# Fields:
# - person_uuid
# - person_name
# - job_title
# - job_type (founder, executive, investor)
# - person_logo_url
#
# Process:
# 1. Filter jobs on:
#     - jobs['org_uuid'] == target_org['org_uuid]
#     - jobs['job_type'] == 'executive'
#     - jobs['started_on'] < target_org['founded_on'] + years_founding_cutoff
#     - jobs['started_on'] >= target_org['founded_on']
# <br/><br/>
# 2. Left merge with people on person_uuid
#
# ## subsequent_orgs - Organisations the alumni of the target organisation are associated with
# Fields:
# - person_uuid
# - subsequent_org_uuid
# - subsequent_org_name
# - subsequent_position_type (founder, executive, investor, board member)
# - funding_amount_usd
#
# Process:
# 1. Left merge alumni_info with jobs on person_uuid for subsequent_orgs_jobs
# 2. Filter on:
#     - subsequent_orgs_jobs['job_type'].isin(['executive', 'board_member', 'advisor'])
# <br/><br/>
# 3. Left merge investments with funding_rounds on funding_round_uuid for investments_info
# 4. Inner merge alumni_info with investments_info on person_uuid and investor_uuid for subsequent_orgs_investments # TODO also add partner investments at VCs
# 5. Concat subsequent_orgs_jobs with subsequent_orgs_investments for subsequent_orgs
# 6. Left merge subsequent_orgs_investments with organisations on org_uuid for final subsequent_orgs_investments

# %% [markdown]
# ## target_org - Information about the target organisation

# %%
target_org = organisations.loc[organisations['org_uuid'] == target_org_uuid][['org_uuid', 'org_name', 'org_country_code', 'org_region', 'org_city', 'short_description', 'category_list', 'total_funding_usd', 'founded_on', 'org_logo_url']]


# Add exit info
target_org = pd.merge(target_org, acquisitons_ipos, how = 'left', on = 'org_uuid')


target_org.head()
# Out:
#                                org_uuid org_name org_country_code  \
# 0  022417b5-4980-6c54-0f3c-6736bbbb1a5e  Spotify              SWE
#
#        org_region   org_city  \
# 0  Stockholms Lan  Stockholm
#
#                                                                                                                      short_description  \
# 0  Spotify is a commercial music streaming service that provides restricted digital content from a range of record labels and artists.
#
#                                          category_list  total_funding_usd  \
# 0  Audio,Cloud Computing,Music,Music Streaming,Podcast       2.085425e+09
#
#   founded_on  \
# 0 2006-04-23
#
#                                                                                             org_logo_url  \
# 0  https://images.crunchbase.com/image/upload/t_cb-default-original/v1475248336/qmsen1jtcy8xgsghzc8z.jpg
#
#   acquirer_uuid exit_type acquirer_name  exit_date acquisition_type  \
# 0           NaN       ipo           NaN 2018-04-03              NaN
#
#    exit_valuation
# 0    2.950000e+10

# %%
export_df = target_org.rename(columns={
    'org_uuid': 'orgUuid',
    'org_name': 'orgName',
    'org_country_code': 'orgCountryCode',
    'org_region': 'orgRegion',
    'org_city': 'orgCity',
    'short_description': 'shortDescription',
    'category_list': 'categoryList',
    'total_funding_usd': 'totalFundingUsd',
    'founded_on': 'foundedOn',
    'org_logo_url': 'orgLogoUrl',
    'exit_type': 'exitType',
    'exit_date': 'exitDate',
    'exit_valuation': 'exitValuation',
    'acquirer_uuid': 'acquirerUuid',
    'acquirer_name': 'acquirerName',
    'acquisition_type': 'acquisitionType',
}).drop(columns = ['categoryList'], axis = 1)

export_df.to_json('data/output/targetOrg_' + target_org_uuid + '.json', orient = 'records')

# %% [markdown]
# ## alumni_info - Information about target organisation alumnis

# %%
executives_target = jobs.loc[
        (jobs['org_uuid'] == target_org_uuid)
        & (jobs['job_type'] == 'executive')
        & (jobs['started_on'] < target_org['founded_on'].values[0] + pd.DateOffset(years = years_founding_cutoff))
        & (jobs['started_on'] >= target_org['founded_on'].values[0] - pd.DateOffset(years = 2)) # Allowing founders to state they've started the company up to 2 year prior to CB foundation date
]

alumni_info = pd.merge(
    executives_target,
    people,
    how = 'left',
    on = 'person_uuid'
)[['person_uuid', 'person_name', 'job_title', 'job_type', 'started_on', 'ended_on', 'person_logo_url']]

alumni_info.head()
# Out:
#                             person_uuid       person_name  \
# 0  39527839-3b48-fb72-2850-197248149dfd         Daniel Ek
# 1  bafe0ce1-653f-1178-b41b-26d90fe5c474  Martin Lorentzon
# 2  c5300174-8173-67f5-1879-ba3b9e4a1d49        Paul Brown
# 3  7e798976-add2-9e56-7283-55e6c893e3bf       Andreas Ehn
# 4  5eee7d5a-4754-8b26-6d70-b6435abfa1c9   Nevyn Bengtsson
#
#                       job_title   job_type started_on   ended_on  \
# 0  Co-Founder, Chairman and CEO  executive 2006-04-01        NaT
# 1                      Chairman  executive 2006-01-01 2016-01-01
# 2   SVP, Strategic Partnerships  executive 2009-03-20        NaT
# 3      Chief Technology Officer  executive 2006-08-01 2009-11-01
# 4            Lead iOS Developer  executive 2008-10-07        NaT
#
#                                                                                          person_logo_url
# 0  https://images.crunchbase.com/image/upload/t_cb-default-original/v1476461851/nqxzswvfqhrl3ik7sb2u.jpg
# 1  https://images.crunchbase.com/image/upload/t_cb-default-original/v1503996438/bxz3zfltdkvlbjjwnwr1.jpg
# 2                  https://images.crunchbase.com/image/upload/t_cb-default-original/bsksoabedkj9j9hei9xi
# 3  https://images.crunchbase.com/image/upload/t_cb-default-original/v1485344129/vquztdeitfwgixbfrfxf.jpg
# 4  https://images.crunchbase.com/image/upload/t_cb-default-original/v1481653184/byrmgewvnkhqzhnuc0qy.jpg

# %%
export_df = alumni_info.drop_duplicates(subset = ['person_uuid'])[['person_uuid', 'person_name', 'job_title', 'job_type', 'started_on', 'ended_on', 'person_logo_url']].rename(columns={
    'person_uuid': 'personUuid',
    'person_name': 'personName',
    'job_title': 'jobTitle',
    'job_type': 'jobType',
    'started_on': 'startedOn',
    'ended_on': 'endedOn',
    'person_logo_url': 'personLogoUrl',
})

export_df.to_json('data/output/alumniInfo_' + target_org_uuid + '.json', orient = 'records')

# %% [markdown]
# ## subsequent_orgs - Organisations the alumni of the target organisation are associated with

# %%
alumni_jobs = jobs.loc[
    jobs['person_uuid'].isin(alumni_info['person_uuid'])
    & jobs['job_type'].isin(['executive', 'board_member', 'advisor'])
]

subsequent_orgs_jobs = (
    pd.merge(alumni_info, alumni_jobs, how = 'left', on = 'person_uuid', suffixes = ['_target', '_subsequent'])
    .drop_duplicates(subset = ['person_uuid', 'job_uuid'])
).rename(columns = {'job_type_subsequent': 'relation_type'})

subsequent_orgs_jobs = subsequent_orgs_jobs.loc[subsequent_orgs_jobs['started_on_target'] < subsequent_orgs_jobs['started_on_subsequent']][['person_uuid', 'org_uuid', 'relation_type', 'job_title_subsequent']]

subsequent_orgs_jobs
# Out:
#                              person_uuid  \
# 5   bafe0ce1-653f-1178-b41b-26d90fe5c474
# 11  7e798976-add2-9e56-7283-55e6c893e3bf
# 15  7e798976-add2-9e56-7283-55e6c893e3bf
# 16  7e798976-add2-9e56-7283-55e6c893e3bf
# 18  7e798976-add2-9e56-7283-55e6c893e3bf
# 19  7e798976-add2-9e56-7283-55e6c893e3bf
# 20  7e798976-add2-9e56-7283-55e6c893e3bf
# 22  5eee7d5a-4754-8b26-6d70-b6435abfa1c9
# 24  4db1d407-b84b-042f-5fc5-649fed6e75d6
# 25  4db1d407-b84b-042f-5fc5-649fed6e75d6
# 26  4db1d407-b84b-042f-5fc5-649fed6e75d6
# 27  4db1d407-b84b-042f-5fc5-649fed6e75d6
# 28  4db1d407-b84b-042f-5fc5-649fed6e75d6
# 29  4db1d407-b84b-042f-5fc5-649fed6e75d6
# 30  4db1d407-b84b-042f-5fc5-649fed6e75d6
# 32  ae779864-fdbc-c059-d4df-4a59e9531c9c
#
#                                 org_uuid relation_type  \
# 5   022417b5-4980-6c54-0f3c-6736bbbb1a5e  board_member
# 11  8477b533-0654-993c-b69e-be52c2ff078e       advisor
# 15  51d94123-97d9-be50-33a7-c1ee3f2bee0f     executive
# 16  352c09ba-37ee-9e0f-e729-6eb9d621adab  board_member
# 18  51d94123-97d9-be50-33a7-c1ee3f2bee0f  board_member
# 19  88b3e5d7-8c01-8428-4f86-3e816285f899     executive
# 20  00daca16-8311-454b-84e0-24a40d16be9c       advisor
# 22  b5dd7211-bdbb-3b8c-b2c5-1627f6408085     executive
# 24  022417b5-4980-6c54-0f3c-6736bbbb1a5e     executive
# 25  022417b5-4980-6c54-0f3c-6736bbbb1a5e       advisor
# 26  87fe9937-1c68-e177-336b-b8b12797453a     executive
# 27  dfdddecb-c719-02ec-56f6-da4f071ab6e6  board_member
# 28  edcba868-67a1-5df3-5cef-5f9a455a30fc       advisor
# 29  2251d3da-7c8c-27e8-a7ae-1797af0432fe       advisor
# 30  6c4affe2-32e4-5502-3e6c-15ceb74d2529       advisor
# 32  f16869c5-e2f5-cfa8-85fa-43adffeabd1f  board_member
#
#                      job_title_subsequent
# 5      Chairman of the Board of Directors
# 11                         Senior Advisor
# 15  Co-Founder & Chief Technology Officer
# 16                     Board of Directors
# 18                           Board member
# 19                         Board director
# 20                                Advisor
# 22                        CTO & Code Poet
# 24       Managing Director, North America
# 25    Senior Member of the Advisory Board
# 26                     Executive Chairman
# 27                  Advisory Board Member
# 28                                Advisor
# 29                                Advisor
# 30                                Advisor
# 32           Non-Executive Board Director

# %%
investments_info = pd.merge(
    investments,
    funding_rounds,
    how = 'left',
    on = 'funding_round_uuid'
)[['org_uuid', 'investor_uuid', 'investment_type', 'announced_on']]

subsequent_orgs_investments = (
    investments_info
    .loc[investments_info['investor_uuid'].isin(alumni_info['person_uuid'])]
    .assign(relation_type = 'investor')
    .assign(job_title_subsequent = 'investor')
    .rename(columns = {'investor_uuid': 'person_uuid'})
)[['person_uuid', 'org_uuid', 'relation_type', 'job_title_subsequent']]

subsequent_orgs_investments
# Out:
#                                  person_uuid  \
# 41758   7e798976-add2-9e56-7283-55e6c893e3bf
# 57789   7e798976-add2-9e56-7283-55e6c893e3bf
# 90632   7e798976-add2-9e56-7283-55e6c893e3bf
# 156088  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 156419  ae779864-fdbc-c059-d4df-4a59e9531c9c
# 190800  7e798976-add2-9e56-7283-55e6c893e3bf
# 213967  7e798976-add2-9e56-7283-55e6c893e3bf
# 263502  7e798976-add2-9e56-7283-55e6c893e3bf
# 266016  7e798976-add2-9e56-7283-55e6c893e3bf
# 268838  7e798976-add2-9e56-7283-55e6c893e3bf
# 271263  7e798976-add2-9e56-7283-55e6c893e3bf
# 271559  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 295979  7e798976-add2-9e56-7283-55e6c893e3bf
# 336459  7e798976-add2-9e56-7283-55e6c893e3bf
# 359500  7e798976-add2-9e56-7283-55e6c893e3bf
# 387005  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 405290  7e798976-add2-9e56-7283-55e6c893e3bf
# 405291  7e798976-add2-9e56-7283-55e6c893e3bf
# 521604  7e798976-add2-9e56-7283-55e6c893e3bf
# 581297  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 692245  39527839-3b48-fb72-2850-197248149dfd
# 796521  39527839-3b48-fb72-2850-197248149dfd
# 862052  39527839-3b48-fb72-2850-197248149dfd
# 866299  7e798976-add2-9e56-7283-55e6c893e3bf
#
#                                     org_uuid relation_type  \
# 41758   f5506198-5d0b-1d56-1d2c-eee2e8ae4339      investor
# 57789   751f9fd0-2255-ddff-1642-3a8a2a3627cf      investor
# 90632   abca185a-3c42-579f-26fb-87d0a534317c      investor
# 156088  108f53d2-590c-87a3-850b-89959140740f      investor
# 156419  f16869c5-e2f5-cfa8-85fa-43adffeabd1f      investor
# 190800  b7df520a-4772-a30e-ddd4-78a587acd7ff      investor
# 213967  48fbf67f-e2dd-a1a8-6e66-1e249c7cb71c      investor
# 263502  0d39cbff-e7d3-db40-504b-0b6d6a5b46bc      investor
# 266016  f6833dde-6118-5915-1a34-7627c55133b7      investor
# 268838  c2c32d7a-0ec0-d5c2-d65e-fa2780ed8977      investor
# 271263  0d39cbff-e7d3-db40-504b-0b6d6a5b46bc      investor
# 271559  90737966-ae35-30a5-ca2d-125b94e429c9      investor
# 295979  00daca16-8311-454b-84e0-24a40d16be9c      investor
# 336459  b036c231-6860-7b23-ca8a-c0d88a0bb103      investor
# 359500  8281b169-5e4f-79c1-dddb-594893977a54      investor
# 387005  90737966-ae35-30a5-ca2d-125b94e429c9      investor
# 405290  88b3e5d7-8c01-8428-4f86-3e816285f899      investor
# 405291  6e73baf7-27e0-4c81-8211-ae2544d40495      investor
# 521604  337115de-de1c-2cf9-b114-5b682668171c      investor
# 581297  032456a4-df14-4bb0-b5a6-5793cd2bdee8      investor
# 692245  0fd55f9d-a10f-44a9-a0b8-981ab5c9ab55      investor
# 796521  64785d22-99d3-4e6e-87ce-d886e8418d8e      investor
# 862052  64785d22-99d3-4e6e-87ce-d886e8418d8e      investor
# 866299  3edbd3cc-1b0b-4ee2-a882-638d7e75b763      investor
#
#        job_title_subsequent
# 41758              investor
# 57789              investor
# 90632              investor
# 156088             investor
# 156419             investor
# 190800             investor
# 213967             investor
# 263502             investor
# 266016             investor
# 268838             investor
# 271263             investor
# 271559             investor
# 295979             investor
# 336459             investor
# 359500             investor
# 387005             investor
# 405290             investor
# 405291             investor
# 521604             investor
# 581297             investor
# 692245             investor
# 796521             investor
# 862052             investor
# 866299             investor

# %%
subsequent_orgs = pd.concat([subsequent_orgs_jobs, subsequent_orgs_investments])

subsequent_orgs.head()
# Out:
#                              person_uuid  \
# 5   bafe0ce1-653f-1178-b41b-26d90fe5c474
# 11  7e798976-add2-9e56-7283-55e6c893e3bf
# 15  7e798976-add2-9e56-7283-55e6c893e3bf
# 16  7e798976-add2-9e56-7283-55e6c893e3bf
# 18  7e798976-add2-9e56-7283-55e6c893e3bf
#
#                                 org_uuid relation_type  \
# 5   022417b5-4980-6c54-0f3c-6736bbbb1a5e  board_member
# 11  8477b533-0654-993c-b69e-be52c2ff078e       advisor
# 15  51d94123-97d9-be50-33a7-c1ee3f2bee0f     executive
# 16  352c09ba-37ee-9e0f-e729-6eb9d621adab  board_member
# 18  51d94123-97d9-be50-33a7-c1ee3f2bee0f  board_member
#
#                      job_title_subsequent
# 5      Chairman of the Board of Directors
# 11                         Senior Advisor
# 15  Co-Founder & Chief Technology Officer
# 16                     Board of Directors
# 18                           Board member

# %%
subsequent_orgs_info = (
    pd.merge(subsequent_orgs, organisations, how = 'left', on = 'org_uuid')
    .rename(columns = {'job_title': 'job_title_subsequent'})
)[['person_uuid', 'org_uuid', 'relation_type', 'job_title_subsequent', 'org_name', 'org_country_code', 'org_city', 'short_description', 'category_list', 'total_funding_usd', 'founded_on', 'org_logo_url']]

subsequent_orgs_info = subsequent_orgs_info.loc[subsequent_orgs_info['org_uuid'] != target_org['org_uuid'].values[0]]


# Add exit info
subsequent_orgs_info = pd.merge(subsequent_orgs_info, acquisitons_ipos, how = 'left', on = 'org_uuid')

subsequent_orgs_info
# Out:
#                              person_uuid  \
# 0   7e798976-add2-9e56-7283-55e6c893e3bf
# 1   7e798976-add2-9e56-7283-55e6c893e3bf
# 2   7e798976-add2-9e56-7283-55e6c893e3bf
# 3   7e798976-add2-9e56-7283-55e6c893e3bf
# 4   7e798976-add2-9e56-7283-55e6c893e3bf
# 5   7e798976-add2-9e56-7283-55e6c893e3bf
# 6   5eee7d5a-4754-8b26-6d70-b6435abfa1c9
# 7   4db1d407-b84b-042f-5fc5-649fed6e75d6
# 8   4db1d407-b84b-042f-5fc5-649fed6e75d6
# 9   4db1d407-b84b-042f-5fc5-649fed6e75d6
# 10  4db1d407-b84b-042f-5fc5-649fed6e75d6
# 11  4db1d407-b84b-042f-5fc5-649fed6e75d6
# 12  ae779864-fdbc-c059-d4df-4a59e9531c9c
# 13  7e798976-add2-9e56-7283-55e6c893e3bf
# 14  7e798976-add2-9e56-7283-55e6c893e3bf
# 15  7e798976-add2-9e56-7283-55e6c893e3bf
# 16  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 17  ae779864-fdbc-c059-d4df-4a59e9531c9c
# 18  7e798976-add2-9e56-7283-55e6c893e3bf
# 19  7e798976-add2-9e56-7283-55e6c893e3bf
# 20  7e798976-add2-9e56-7283-55e6c893e3bf
# 21  7e798976-add2-9e56-7283-55e6c893e3bf
# 22  7e798976-add2-9e56-7283-55e6c893e3bf
# 23  7e798976-add2-9e56-7283-55e6c893e3bf
# 24  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 25  7e798976-add2-9e56-7283-55e6c893e3bf
# 26  7e798976-add2-9e56-7283-55e6c893e3bf
# 27  7e798976-add2-9e56-7283-55e6c893e3bf
# 28  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 29  7e798976-add2-9e56-7283-55e6c893e3bf
# 30  7e798976-add2-9e56-7283-55e6c893e3bf
# 31  7e798976-add2-9e56-7283-55e6c893e3bf
# 32  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 33  39527839-3b48-fb72-2850-197248149dfd
# 34  39527839-3b48-fb72-2850-197248149dfd
# 35  39527839-3b48-fb72-2850-197248149dfd
# 36  7e798976-add2-9e56-7283-55e6c893e3bf
#
#                                 org_uuid relation_type  \
# 0   8477b533-0654-993c-b69e-be52c2ff078e       advisor
# 1   51d94123-97d9-be50-33a7-c1ee3f2bee0f     executive
# 2   352c09ba-37ee-9e0f-e729-6eb9d621adab  board_member
# 3   51d94123-97d9-be50-33a7-c1ee3f2bee0f  board_member
# 4   88b3e5d7-8c01-8428-4f86-3e816285f899     executive
# 5   00daca16-8311-454b-84e0-24a40d16be9c       advisor
# 6   b5dd7211-bdbb-3b8c-b2c5-1627f6408085     executive
# 7   87fe9937-1c68-e177-336b-b8b12797453a     executive
# 8   dfdddecb-c719-02ec-56f6-da4f071ab6e6  board_member
# 9   edcba868-67a1-5df3-5cef-5f9a455a30fc       advisor
# 10  2251d3da-7c8c-27e8-a7ae-1797af0432fe       advisor
# 11  6c4affe2-32e4-5502-3e6c-15ceb74d2529       advisor
# 12  f16869c5-e2f5-cfa8-85fa-43adffeabd1f  board_member
# 13  f5506198-5d0b-1d56-1d2c-eee2e8ae4339      investor
# 14  751f9fd0-2255-ddff-1642-3a8a2a3627cf      investor
# 15  abca185a-3c42-579f-26fb-87d0a534317c      investor
# 16  108f53d2-590c-87a3-850b-89959140740f      investor
# 17  f16869c5-e2f5-cfa8-85fa-43adffeabd1f      investor
# 18  b7df520a-4772-a30e-ddd4-78a587acd7ff      investor
# 19  48fbf67f-e2dd-a1a8-6e66-1e249c7cb71c      investor
# 20  0d39cbff-e7d3-db40-504b-0b6d6a5b46bc      investor
# 21  f6833dde-6118-5915-1a34-7627c55133b7      investor
# 22  c2c32d7a-0ec0-d5c2-d65e-fa2780ed8977      investor
# 23  0d39cbff-e7d3-db40-504b-0b6d6a5b46bc      investor
# 24  90737966-ae35-30a5-ca2d-125b94e429c9      investor
# 25  00daca16-8311-454b-84e0-24a40d16be9c      investor
# 26  b036c231-6860-7b23-ca8a-c0d88a0bb103      investor
# 27  8281b169-5e4f-79c1-dddb-594893977a54      investor
# 28  90737966-ae35-30a5-ca2d-125b94e429c9      investor
# 29  88b3e5d7-8c01-8428-4f86-3e816285f899      investor
# 30  6e73baf7-27e0-4c81-8211-ae2544d40495      investor
# 31  337115de-de1c-2cf9-b114-5b682668171c      investor
# 32  032456a4-df14-4bb0-b5a6-5793cd2bdee8      investor
# 33  0fd55f9d-a10f-44a9-a0b8-981ab5c9ab55      investor
# 34  64785d22-99d3-4e6e-87ce-d886e8418d8e      investor
# 35  64785d22-99d3-4e6e-87ce-d886e8418d8e      investor
# 36  3edbd3cc-1b0b-4ee2-a882-638d7e75b763      investor
#
#                      job_title_subsequent             org_name  \
# 0                          Senior Advisor           Videoplaza
# 1   Co-Founder & Chief Technology Officer                Wrapp
# 2                      Board of Directors          Shootitlive
# 3                            Board member                Wrapp
# 4                          Board director             Automile
# 5                                 Advisor               Antler
# 6                         CTO & Code Poet             Lookback
# 7                      Executive Chairman             Pluto TV
# 8                   Advisory Board Member             Ericsson
# 9                                 Advisor           Threadless
# 10                                Advisor        8tracks Radio
# 11                                Advisor      Recorded Future
# 12           Non-Executive Board Director           Movebubble
# 13                               investor            Tripbirds
# 14                               investor               Opbeat
# 15                               investor                 Clue
# 16                               investor          Student.com
# 17                               investor           Movebubble
# 18                               investor              Sunrise
# 19                               investor              Timekit
# 20                               investor        Triple Global
# 21                               investor                Visor
# 22                               investor               RiseML
# 23                               investor        Triple Global
# 24                               investor                Sniph
# 25                               investor               Antler
# 26                               investor             Mavenoid
# 27                               investor             Red Flag
# 28                               investor                Sniph
# 29                               investor             Automile
# 30                               investor               Aspire
# 31                               investor  Single Technologies
# 32                               investor            Coffydoor
# 33                               investor          HJN Sverige
# 34                               investor       H2 Green Steel
# 35                               investor       H2 Green Steel
# 36                               investor              Prog.AI
#
#    org_country_code       org_city  \
# 0               GBR         London
# 1               SWE      Stockholm
# 2               SWE      Stockholm
# 3               SWE      Stockholm
# 4               USA      Palo Alto
# 5               SGP      Singapore
# 6               USA     Menlo Park
# 7               USA    Los Angeles
# 8               SWE          Kista
# 9               USA        Chicago
# 10              USA  San Francisco
# 11              USA     Somerville
# 12              GBR         London
# 13              SWE      Stockholm
# 14              USA  San Francisco
# 15              DEU         Berlin
# 16              GBR         London
# 17              GBR         London
# 18              FRA          Paris
# 19              USA  San Francisco
# 20              SWE      Stockholm
# 21              USA     Long Beach
# 22              DEU         Berlin
# 23              SWE      Stockholm
# 24              SWE      Stockholm
# 25              SGP      Singapore
# 26              SWE      Stockholm
# 27              GBR         London
# 28              SWE      Stockholm
# 29              USA      Palo Alto
# 30              SGP      Singapore
# 31              SWE      Stockholm
# 32              SWE      Stockholm
# 33              SWE      Stockholm
# 34              SWE      Stockholm
# 35              SWE      Stockholm
# 36              USA  San Francisco
#
#                                                                                                                              short_description  \
# 0   Our mission is to empower broadcasters & video publishers to build profitable and sustainable businesses in the internet-delivered TV worl
# 1                                                                      Wrapp is The New Standard for rewarding purchases and customer loyalty.
# 2                                   Shootitlive designs and delivers a live publishing platform for publishers and professional photographers.
# 3                                                                      Wrapp is The New Standard for rewarding purchases and customer loyalty.
# 4                                                                   Automile offers frictionless tracking and management of fleets and assets.
# 5                                                 Antler is the investor backing the world's most driven founders, from day zero to greatness.
# 6                                                                           Lookback is a platform for easy-to-use software testing solutions.
# 7                                                                        Pluto TV is the leading free streaming television service in America.
# 8                                               Ericsson is an information and communications technology company that offers network services.
# 9       Threadless is a global community-driven design platform featuring designs created by various designers, artists and general consumers.
# 10                    8tracks is an internet radio and social network that streams user-curated song playlists that contain at least 8 tracks.
# 11                                                            Recorded Future develops a single intelligence platform for enterprise security.
# 12                                                                                  Movebubble is a property rental app in London & Manchester
# 13   Tripbirds is a travel site providing hotel listings by integrating with Facebook and Instagram and enabling travelers book hotels online.
# 14           Opbeat is an open source application performance monitoring that identifies performance issues with a breakdown that makes sense.
# 15                                                                       Clue is a female health application for period and fertility tracking
# 16                                    Student.com is a marketplace for international student housing, helping students find their home abroad.
# 17                                                                                  Movebubble is a property rental app in London & Manchester
# 18               Sunrise is a free calendar app specifically designed to make your life easier. Available on Android, iPhone, iPad, Mac & Web.
# 19                     Timekit empowers developers and designers through a set of unified APIs that deliver the entire booking infrastructure.
# 20                                               Triple is a marketplace for social traveling where anyone can host experiences for travelers.
# 21                                                                                                                 Tax advisory for the masses
# 22                                            RiseML creates software to help machine learning teams scale their deep learning infrastructure.
# 23                                               Triple is a marketplace for social traveling where anyone can host experiences for travelers.
# 24                                              Sniph is a smart subscription service for perfume, which makes it easy to discover new scents.
# 25                                                Antler is the investor backing the world's most driven founders, from day zero to greatness.
# 26                                         Mavenoid develops an AI-driven product support and troubleshooting platform for hardware companies.
# 27                                                       Red Flag develops an automated accounting, expenses, and invoicing platform for SMEs.
# 28                                              Sniph is a smart subscription service for perfume, which makes it easy to discover new scents.
# 29                                                                  Automile offers frictionless tracking and management of fleets and assets.
# 30                                                         Aspire is a financial platform providing earnings, payment, and expense management.
# 31                                                     SINGLE TECHNOLOGIES develops a new type of (3-D) DNA sequencing system to improve Life.
# 32                       Coffydoor is a subscription service that delivers premium coffee capsules at a fair price, directly to your doorstep.
# 33                      HJN Sverige is a technology business based in Sweden that specializes in machine learning and artificial intelligence.
# 34                H2 Green Steel operates a steel production plant to accelerate the decarbonization of the steel industry using green energy.
# 35                H2 Green Steel operates a steel production plant to accelerate the decarbonization of the steel industry using green energy.
# 36  Prog.AI helps to find developers on technical proficiency, libraries they have used, even contributions they have made to GitHub projects.
#
#                                                                                      category_list  \
# 0                                                                     Advertising,Publishing,Video
# 1                                                       Apps,FinTech,Gift Card,Mobile,Social Media
# 2                                                             Business Development,News,Publishing
# 3                                                       Apps,FinTech,Gift Card,Mobile,Social Media
# 4                                                      Automotive,B2B,Developer APIs,SaaS,Software
# 5                                                       Finance,Financial Services,Venture Capital
# 6                                                         Mobile,Product Design,Software,UX Design
# 7                                      Apps,Internet,Media and Entertainment,Video,Video Streaming
# 8                                        Information Technology,Internet,Mobile,Telecommunications
# 9                                              Communities,Crowdsourcing,E-Commerce,Product Design
# 10                                                    Internet Radio,Media and Entertainment,Music
# 11                                          Analytics,Cyber Security,Intelligent Systems,Real Time
# 12                                                                     Apps,Internet,Mobile,Rental
# 13                               Information Services,Information Technology,Social Network,Travel
# 14                                                          Computer,Internet,Open Source,Software
# 15                                             Apps,Fertility,Health Care,mHealth,Wellness,Women's
# 16                                                                          Consulting,Marketplace
# 17                                                                     Apps,Internet,Mobile,Rental
# 18                                                               Apps,Email,Events,Internet,Mobile
# 19                                                                  Developer APIs,Mobile,Software
# 20                                                            Leisure,Marketing,Marketplace,Travel
# 21                                                                      Financial Services,FinTech
# 22                                 Artificial Intelligence (AI),Internet,Machine Learning,Software
# 23                                                            Leisure,Marketing,Marketplace,Travel
# 24                                                                        Beauty,Fashion,Lifestyle
# 25                                                      Finance,Financial Services,Venture Capital
# 26  Artificial Intelligence (AI),Customer Service,Hardware,Industrial Automation,Technical Support
# 27                                                                 Accounting,Credit,Payments,SaaS
# 28                                                                        Beauty,Fashion,Lifestyle
# 29                                                     Automotive,B2B,Developer APIs,SaaS,Software
# 30                                  Banking,Financial Services,FinTech,Small and Medium Businesses
# 31                                           Biotechnology,Genetics,Health Care,Health Diagnostics
# 32                                                                        Coffee,Food and Beverage
# 33                   Artificial Intelligence (AI),Information Technology,Machine Learning,Software
# 34                                                    CleanTech,GreenTech,Industrial Manufacturing
# 35                                                    CleanTech,GreenTech,Industrial Manufacturing
# 36                              Developer Platform,Email Marketing,Information Services,Recruiting
#
#     total_funding_usd founded_on  \
# 0        1.742782e+07 2007-11-01
# 1        3.754012e+07 2011-05-01
# 2        3.111380e+05 2008-05-05
# 3        3.754012e+07 2011-05-01
# 4        4.730613e+07 2013-01-01
# 5        8.220000e+07 2017-01-01
# 6        8.200000e+06 2013-01-01
# 7        5.180000e+07 2013-01-01
# 8        1.589787e+09 1876-01-01
# 9        0.000000e+00 2000-11-01
# 10       8.989857e+06 2008-08-08
# 11       6.922596e+07 2009-01-01
# 12       4.218114e+06 2013-01-01
# 13       7.400000e+05 2011-06-01
# 14       2.800000e+06 2012-01-01
# 15       6.471121e+07 2012-01-01
# 16       8.000000e+07 2011-01-01
# 17       4.218114e+06 2013-01-01
# 18       1.029596e+07 2012-12-01
# 19       1.700000e+06 2015-01-01
# 20       1.060652e+06 2016-10-01
# 21       1.550000e+07 2016-01-01
# 22       9.106000e+05 2016-09-01
# 23       1.060652e+06 2016-10-01
# 24       1.778362e+06 2015-01-01
# 25       8.220000e+07 2017-01-01
# 26       3.990000e+07 2017-01-01
# 27       7.891927e+06 2016-01-01
# 28       1.778362e+06 2015-01-01
# 29       4.730613e+07 2013-01-01
# 30       2.995000e+08 2018-01-01
# 31       9.246416e+06 2013-01-01
# 32       0.000000e+00 2020-01-01
# 33       1.930000e+06 2018-01-01
# 34       1.091596e+10 2020-01-01
# 35       1.091596e+10 2020-01-01
# 36       1.000000e+06 2022-03-01
#
#                                                                                                          org_logo_url  \
# 0   https://images.crunchbase.com/image/upload/t_cb-default-original/v1397189977/ce8229a5e9e6f065e84bf41437f2fa87.png
# 1                               https://images.crunchbase.com/image/upload/t_cb-default-original/s4t0zdisweychs5tfxfy
# 2   https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180596/33c4c79dd70482e40aecadb6beb0562c.png
# 3                               https://images.crunchbase.com/image/upload/t_cb-default-original/s4t0zdisweychs5tfxfy
# 4               https://images.crunchbase.com/image/upload/t_cb-default-original/v1482521626/jakzy9ivmegl8o7sroed.png
# 5                               https://images.crunchbase.com/image/upload/t_cb-default-original/c7spuuktidov5ckclnoy
# 6               https://images.crunchbase.com/image/upload/t_cb-default-original/v1426358818/u8ejo6w7vvi5ectctfjf.png
# 7                               https://images.crunchbase.com/image/upload/t_cb-default-original/ecdphkz2zo8b7xr8usq4
# 8                               https://images.crunchbase.com/image/upload/t_cb-default-original/cmazrdxlkfgyxjax4p3x
# 9   https://images.crunchbase.com/image/upload/t_cb-default-original/v1397182106/2e87adfa6083a78dab4955b3f032672d.png
# 10  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397195325/8a34e592d7cae593ad6be7b61087f699.png
# 11                              https://images.crunchbase.com/image/upload/t_cb-default-original/ktnj3i4jfhgll9perlnr
# 12                              https://images.crunchbase.com/image/upload/t_cb-default-original/u14fyp9bxljfiapxmmnw
# 13  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180437/86eac0fefbf4d659dc4bfdaf5c844276.jpg
# 14                              https://images.crunchbase.com/image/upload/t_cb-default-original/fddgdptrebo9ve6keq6b
# 15  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180759/d479cbca0b9b6d20b9d58be75e58f801.png
# 16              https://images.crunchbase.com/image/upload/t_cb-default-original/v1444834430/kkwurcm0qfjarpyrkbh4.jpg
# 17                              https://images.crunchbase.com/image/upload/t_cb-default-original/u14fyp9bxljfiapxmmnw
# 18  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397187893/933eeffebf13e218faeff0e90e68d15f.png
# 19              https://images.crunchbase.com/image/upload/t_cb-default-original/v1484676531/abooje82p63ukrwgkg4t.png
# 20              https://images.crunchbase.com/image/upload/t_cb-default-original/v1505970694/dxbyrihzm6t5rqoatepr.jpg
# 21                              https://images.crunchbase.com/image/upload/t_cb-default-original/srlnpw7ipfjvl12alkxe
# 22                              https://images.crunchbase.com/image/upload/t_cb-default-original/gicxkrqdxi6y0ctlrn6z
# 23              https://images.crunchbase.com/image/upload/t_cb-default-original/v1505970694/dxbyrihzm6t5rqoatepr.jpg
# 24              https://images.crunchbase.com/image/upload/t_cb-default-original/v1459252193/bum3bae7jsxlg5jlwdfn.jpg
# 25                              https://images.crunchbase.com/image/upload/t_cb-default-original/c7spuuktidov5ckclnoy
# 26                              https://images.crunchbase.com/image/upload/t_cb-default-original/ai8n6mffccs8wx4jpup7
# 27              https://images.crunchbase.com/image/upload/t_cb-default-original/v1489666894/jldataa4avrid2ikyzlf.png
# 28              https://images.crunchbase.com/image/upload/t_cb-default-original/v1459252193/bum3bae7jsxlg5jlwdfn.jpg
# 29              https://images.crunchbase.com/image/upload/t_cb-default-original/v1482521626/jakzy9ivmegl8o7sroed.png
# 30                              https://images.crunchbase.com/image/upload/t_cb-default-original/elkxxs4m1q0w660kc5af
# 31              https://images.crunchbase.com/image/upload/t_cb-default-original/v1456721192/y5gwbkz49rz9fpzxs9ns.png
# 32                              https://images.crunchbase.com/image/upload/t_cb-default-original/lp442kynz1dwrkitphuo
# 33                                                                                                                NaN
# 34                              https://images.crunchbase.com/image/upload/t_cb-default-original/gkg0q7zvupqpfjsgxoua
# 35                              https://images.crunchbase.com/image/upload/t_cb-default-original/gkg0q7zvupqpfjsgxoua
# 36                              https://images.crunchbase.com/image/upload/t_cb-default-original/wsr2auvypek7xetlzdkz
#
#                            acquirer_uuid    exit_type  \
# 0   55272742-9158-69f1-31a1-364322caff54  acquisition
# 1   158ee541-b480-1407-83c3-d28ff03babc4  acquisition
# 2   dc6f66bd-0521-ab5d-dd2b-e60aca283151  acquisition
# 3   158ee541-b480-1407-83c3-d28ff03babc4  acquisition
# 4                                    NaN          NaN
# 5                                    NaN          NaN
# 6                                    NaN          NaN
# 7   4522b60d-0b04-827e-2b6c-6eaf236cf636  acquisition
# 8   8b794550-2ad2-4a1a-9317-b71898187d27  acquisition
# 9                                    NaN          NaN
# 10                                   NaN          NaN
# 11  6efb9171-a87b-212d-f399-b0613da7b1c9  acquisition
# 12                                   NaN          NaN
# 13                                   NaN          NaN
# 14  e0d34498-56d2-ff04-5ff1-4775d10fcc09  acquisition
# 15                                   NaN          NaN
# 16                                   NaN          NaN
# 17                                   NaN          NaN
# 18  fd80725f-53fc-7009-9878-aeecf1e9ffbb  acquisition
# 19  eb7cef2b-ff40-c0e8-38c2-c6a2988389df  acquisition
# 20                                   NaN          NaN
# 21                                   NaN          NaN
# 22                                   NaN          NaN
# 23                                   NaN          NaN
# 24                                   NaN          NaN
# 25                                   NaN          NaN
# 26                                   NaN          NaN
# 27  6d942ddd-5fe8-23fe-093d-d054a5ceca1a  acquisition
# 28                                   NaN          NaN
# 29                                   NaN          NaN
# 30                                   NaN          NaN
# 31                                   NaN          NaN
# 32                                   NaN          NaN
# 33                                   NaN          NaN
# 34                                   NaN          NaN
# 35                                   NaN          NaN
# 36                                   NaN          NaN
#
#                                      acquirer_name  exit_date  \
# 0                                            Dalet 2014-10-20
# 1                                           Meniga 2019-01-10
# 2                                TT Nyhetsbyran AB 2016-09-30
# 3                                           Meniga 2019-01-10
# 4                                              NaN        NaT
# 5                                              NaN        NaT
# 6                                              NaN        NaT
# 7   VIACOM PARAMOUNT on contract at CBS PARAMOUNT+ 2019-01-22
# 8                                          Bizitek 2009-06-01
# 9                                              NaN        NaT
# 10                                             NaN        NaT
# 11                                Insight Partners 2019-05-30
# 12                                             NaN        NaT
# 13                                             NaN        NaT
# 14                                         Elastic 2017-06-22
# 15                                             NaN        NaT
# 16                                             NaN        NaT
# 17                                             NaN        NaT
# 18                                       Microsoft 2015-02-04
# 19                                    Tulip Retail 2020-11-24
# 20                                             NaN        NaT
# 21                                             NaN        NaT
# 22                                             NaN        NaT
# 23                                             NaN        NaT
# 24                                             NaN        NaT
# 25                                             NaN        NaT
# 26                                             NaN        NaT
# 27                                           Bokio 2020-04-21
# 28                                             NaN        NaT
# 29                                             NaN        NaT
# 30                                             NaN        NaT
# 31                                             NaN        NaT
# 32                                             NaN        NaT
# 33                                             NaN        NaT
# 34                                             NaN        NaT
# 35                                             NaN        NaT
# 36                                             NaN        NaT
#
#    acquisition_type  exit_valuation
# 0       acquisition             NaN
# 1       acquisition             NaN
# 2       acquisition             NaN
# 3       acquisition             NaN
# 4               NaN             NaN
# 5               NaN             NaN
# 6               NaN             NaN
# 7       acquisition     340000000.0
# 8               NaN             NaN
# 9               NaN             NaN
# 10              NaN             NaN
# 11      acquisition     780000000.0
# 12              NaN             NaN
# 13              NaN             NaN
# 14      acquisition             NaN
# 15              NaN             NaN
# 16              NaN             NaN
# 17              NaN             NaN
# 18      acquisition     100000000.0
# 19      acquisition             NaN
# 20              NaN             NaN
# 21              NaN             NaN
# 22              NaN             NaN
# 23              NaN             NaN
# 24              NaN             NaN
# 25              NaN             NaN
# 26              NaN             NaN
# 27            merge             NaN
# 28              NaN             NaN
# 29              NaN             NaN
# 30              NaN             NaN
# 31              NaN             NaN
# 32              NaN             NaN
# 33              NaN             NaN
# 34              NaN             NaN
# 35              NaN             NaN
# 36              NaN             NaN

# %% [markdown]
# ## relations - Relationships between target org people and subsequent org

# %%
relations = subsequent_orgs_info[['person_uuid', 'org_uuid', 'relation_type', 'job_title_subsequent', 'org_logo_url']]

relations
# Out:
#                              person_uuid  \
# 0   7e798976-add2-9e56-7283-55e6c893e3bf
# 1   7e798976-add2-9e56-7283-55e6c893e3bf
# 2   7e798976-add2-9e56-7283-55e6c893e3bf
# 3   7e798976-add2-9e56-7283-55e6c893e3bf
# 4   7e798976-add2-9e56-7283-55e6c893e3bf
# 5   7e798976-add2-9e56-7283-55e6c893e3bf
# 6   5eee7d5a-4754-8b26-6d70-b6435abfa1c9
# 7   4db1d407-b84b-042f-5fc5-649fed6e75d6
# 8   4db1d407-b84b-042f-5fc5-649fed6e75d6
# 9   4db1d407-b84b-042f-5fc5-649fed6e75d6
# 10  4db1d407-b84b-042f-5fc5-649fed6e75d6
# 11  4db1d407-b84b-042f-5fc5-649fed6e75d6
# 12  ae779864-fdbc-c059-d4df-4a59e9531c9c
# 13  7e798976-add2-9e56-7283-55e6c893e3bf
# 14  7e798976-add2-9e56-7283-55e6c893e3bf
# 15  7e798976-add2-9e56-7283-55e6c893e3bf
# 16  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 17  ae779864-fdbc-c059-d4df-4a59e9531c9c
# 18  7e798976-add2-9e56-7283-55e6c893e3bf
# 19  7e798976-add2-9e56-7283-55e6c893e3bf
# 20  7e798976-add2-9e56-7283-55e6c893e3bf
# 21  7e798976-add2-9e56-7283-55e6c893e3bf
# 22  7e798976-add2-9e56-7283-55e6c893e3bf
# 23  7e798976-add2-9e56-7283-55e6c893e3bf
# 24  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 25  7e798976-add2-9e56-7283-55e6c893e3bf
# 26  7e798976-add2-9e56-7283-55e6c893e3bf
# 27  7e798976-add2-9e56-7283-55e6c893e3bf
# 28  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 29  7e798976-add2-9e56-7283-55e6c893e3bf
# 30  7e798976-add2-9e56-7283-55e6c893e3bf
# 31  7e798976-add2-9e56-7283-55e6c893e3bf
# 32  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 33  39527839-3b48-fb72-2850-197248149dfd
# 34  39527839-3b48-fb72-2850-197248149dfd
# 35  39527839-3b48-fb72-2850-197248149dfd
# 36  7e798976-add2-9e56-7283-55e6c893e3bf
#
#                                 org_uuid relation_type  \
# 0   8477b533-0654-993c-b69e-be52c2ff078e       advisor
# 1   51d94123-97d9-be50-33a7-c1ee3f2bee0f     executive
# 2   352c09ba-37ee-9e0f-e729-6eb9d621adab  board_member
# 3   51d94123-97d9-be50-33a7-c1ee3f2bee0f  board_member
# 4   88b3e5d7-8c01-8428-4f86-3e816285f899     executive
# 5   00daca16-8311-454b-84e0-24a40d16be9c       advisor
# 6   b5dd7211-bdbb-3b8c-b2c5-1627f6408085     executive
# 7   87fe9937-1c68-e177-336b-b8b12797453a     executive
# 8   dfdddecb-c719-02ec-56f6-da4f071ab6e6  board_member
# 9   edcba868-67a1-5df3-5cef-5f9a455a30fc       advisor
# 10  2251d3da-7c8c-27e8-a7ae-1797af0432fe       advisor
# 11  6c4affe2-32e4-5502-3e6c-15ceb74d2529       advisor
# 12  f16869c5-e2f5-cfa8-85fa-43adffeabd1f  board_member
# 13  f5506198-5d0b-1d56-1d2c-eee2e8ae4339      investor
# 14  751f9fd0-2255-ddff-1642-3a8a2a3627cf      investor
# 15  abca185a-3c42-579f-26fb-87d0a534317c      investor
# 16  108f53d2-590c-87a3-850b-89959140740f      investor
# 17  f16869c5-e2f5-cfa8-85fa-43adffeabd1f      investor
# 18  b7df520a-4772-a30e-ddd4-78a587acd7ff      investor
# 19  48fbf67f-e2dd-a1a8-6e66-1e249c7cb71c      investor
# 20  0d39cbff-e7d3-db40-504b-0b6d6a5b46bc      investor
# 21  f6833dde-6118-5915-1a34-7627c55133b7      investor
# 22  c2c32d7a-0ec0-d5c2-d65e-fa2780ed8977      investor
# 23  0d39cbff-e7d3-db40-504b-0b6d6a5b46bc      investor
# 24  90737966-ae35-30a5-ca2d-125b94e429c9      investor
# 25  00daca16-8311-454b-84e0-24a40d16be9c      investor
# 26  b036c231-6860-7b23-ca8a-c0d88a0bb103      investor
# 27  8281b169-5e4f-79c1-dddb-594893977a54      investor
# 28  90737966-ae35-30a5-ca2d-125b94e429c9      investor
# 29  88b3e5d7-8c01-8428-4f86-3e816285f899      investor
# 30  6e73baf7-27e0-4c81-8211-ae2544d40495      investor
# 31  337115de-de1c-2cf9-b114-5b682668171c      investor
# 32  032456a4-df14-4bb0-b5a6-5793cd2bdee8      investor
# 33  0fd55f9d-a10f-44a9-a0b8-981ab5c9ab55      investor
# 34  64785d22-99d3-4e6e-87ce-d886e8418d8e      investor
# 35  64785d22-99d3-4e6e-87ce-d886e8418d8e      investor
# 36  3edbd3cc-1b0b-4ee2-a882-638d7e75b763      investor
#
#                      job_title_subsequent  \
# 0                          Senior Advisor
# 1   Co-Founder & Chief Technology Officer
# 2                      Board of Directors
# 3                            Board member
# 4                          Board director
# 5                                 Advisor
# 6                         CTO & Code Poet
# 7                      Executive Chairman
# 8                   Advisory Board Member
# 9                                 Advisor
# 10                                Advisor
# 11                                Advisor
# 12           Non-Executive Board Director
# 13                               investor
# 14                               investor
# 15                               investor
# 16                               investor
# 17                               investor
# 18                               investor
# 19                               investor
# 20                               investor
# 21                               investor
# 22                               investor
# 23                               investor
# 24                               investor
# 25                               investor
# 26                               investor
# 27                               investor
# 28                               investor
# 29                               investor
# 30                               investor
# 31                               investor
# 32                               investor
# 33                               investor
# 34                               investor
# 35                               investor
# 36                               investor
#
#                                                                                                          org_logo_url
# 0   https://images.crunchbase.com/image/upload/t_cb-default-original/v1397189977/ce8229a5e9e6f065e84bf41437f2fa87.png
# 1                               https://images.crunchbase.com/image/upload/t_cb-default-original/s4t0zdisweychs5tfxfy
# 2   https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180596/33c4c79dd70482e40aecadb6beb0562c.png
# 3                               https://images.crunchbase.com/image/upload/t_cb-default-original/s4t0zdisweychs5tfxfy
# 4               https://images.crunchbase.com/image/upload/t_cb-default-original/v1482521626/jakzy9ivmegl8o7sroed.png
# 5                               https://images.crunchbase.com/image/upload/t_cb-default-original/c7spuuktidov5ckclnoy
# 6               https://images.crunchbase.com/image/upload/t_cb-default-original/v1426358818/u8ejo6w7vvi5ectctfjf.png
# 7                               https://images.crunchbase.com/image/upload/t_cb-default-original/ecdphkz2zo8b7xr8usq4
# 8                               https://images.crunchbase.com/image/upload/t_cb-default-original/cmazrdxlkfgyxjax4p3x
# 9   https://images.crunchbase.com/image/upload/t_cb-default-original/v1397182106/2e87adfa6083a78dab4955b3f032672d.png
# 10  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397195325/8a34e592d7cae593ad6be7b61087f699.png
# 11                              https://images.crunchbase.com/image/upload/t_cb-default-original/ktnj3i4jfhgll9perlnr
# 12                              https://images.crunchbase.com/image/upload/t_cb-default-original/u14fyp9bxljfiapxmmnw
# 13  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180437/86eac0fefbf4d659dc4bfdaf5c844276.jpg
# 14                              https://images.crunchbase.com/image/upload/t_cb-default-original/fddgdptrebo9ve6keq6b
# 15  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180759/d479cbca0b9b6d20b9d58be75e58f801.png
# 16              https://images.crunchbase.com/image/upload/t_cb-default-original/v1444834430/kkwurcm0qfjarpyrkbh4.jpg
# 17                              https://images.crunchbase.com/image/upload/t_cb-default-original/u14fyp9bxljfiapxmmnw
# 18  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397187893/933eeffebf13e218faeff0e90e68d15f.png
# 19              https://images.crunchbase.com/image/upload/t_cb-default-original/v1484676531/abooje82p63ukrwgkg4t.png
# 20              https://images.crunchbase.com/image/upload/t_cb-default-original/v1505970694/dxbyrihzm6t5rqoatepr.jpg
# 21                              https://images.crunchbase.com/image/upload/t_cb-default-original/srlnpw7ipfjvl12alkxe
# 22                              https://images.crunchbase.com/image/upload/t_cb-default-original/gicxkrqdxi6y0ctlrn6z
# 23              https://images.crunchbase.com/image/upload/t_cb-default-original/v1505970694/dxbyrihzm6t5rqoatepr.jpg
# 24              https://images.crunchbase.com/image/upload/t_cb-default-original/v1459252193/bum3bae7jsxlg5jlwdfn.jpg
# 25                              https://images.crunchbase.com/image/upload/t_cb-default-original/c7spuuktidov5ckclnoy
# 26                              https://images.crunchbase.com/image/upload/t_cb-default-original/ai8n6mffccs8wx4jpup7
# 27              https://images.crunchbase.com/image/upload/t_cb-default-original/v1489666894/jldataa4avrid2ikyzlf.png
# 28              https://images.crunchbase.com/image/upload/t_cb-default-original/v1459252193/bum3bae7jsxlg5jlwdfn.jpg
# 29              https://images.crunchbase.com/image/upload/t_cb-default-original/v1482521626/jakzy9ivmegl8o7sroed.png
# 30                              https://images.crunchbase.com/image/upload/t_cb-default-original/elkxxs4m1q0w660kc5af
# 31              https://images.crunchbase.com/image/upload/t_cb-default-original/v1456721192/y5gwbkz49rz9fpzxs9ns.png
# 32                              https://images.crunchbase.com/image/upload/t_cb-default-original/lp442kynz1dwrkitphuo
# 33                                                                                                                NaN
# 34                              https://images.crunchbase.com/image/upload/t_cb-default-original/gkg0q7zvupqpfjsgxoua
# 35                              https://images.crunchbase.com/image/upload/t_cb-default-original/gkg0q7zvupqpfjsgxoua
# 36                              https://images.crunchbase.com/image/upload/t_cb-default-original/wsr2auvypek7xetlzdkz

# %%
export_df = relations.rename(columns={
    'person_uuid': 'personUuid',
    'org_uuid': 'orgUuid',
    'relation_type': 'relationType',
    'job_title_subsequent': 'jobTitleSubsequent',
    'org_logo_url': 'orgLogoUrl',
})

export_df.to_json('data/output/relations_' + target_org_uuid + '.json', orient = 'records')

# %% [markdown]
# ## subsequent_orgs_info - Finalisation (only having org info in there)

# %%
subsequent_orgs_info
# Out:
#                              person_uuid  \
# 0   7e798976-add2-9e56-7283-55e6c893e3bf
# 1   7e798976-add2-9e56-7283-55e6c893e3bf
# 2   7e798976-add2-9e56-7283-55e6c893e3bf
# 3   7e798976-add2-9e56-7283-55e6c893e3bf
# 4   7e798976-add2-9e56-7283-55e6c893e3bf
# 5   7e798976-add2-9e56-7283-55e6c893e3bf
# 6   5eee7d5a-4754-8b26-6d70-b6435abfa1c9
# 7   4db1d407-b84b-042f-5fc5-649fed6e75d6
# 8   4db1d407-b84b-042f-5fc5-649fed6e75d6
# 9   4db1d407-b84b-042f-5fc5-649fed6e75d6
# 10  4db1d407-b84b-042f-5fc5-649fed6e75d6
# 11  4db1d407-b84b-042f-5fc5-649fed6e75d6
# 12  ae779864-fdbc-c059-d4df-4a59e9531c9c
# 13  7e798976-add2-9e56-7283-55e6c893e3bf
# 14  7e798976-add2-9e56-7283-55e6c893e3bf
# 15  7e798976-add2-9e56-7283-55e6c893e3bf
# 16  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 17  ae779864-fdbc-c059-d4df-4a59e9531c9c
# 18  7e798976-add2-9e56-7283-55e6c893e3bf
# 19  7e798976-add2-9e56-7283-55e6c893e3bf
# 20  7e798976-add2-9e56-7283-55e6c893e3bf
# 21  7e798976-add2-9e56-7283-55e6c893e3bf
# 22  7e798976-add2-9e56-7283-55e6c893e3bf
# 23  7e798976-add2-9e56-7283-55e6c893e3bf
# 24  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 25  7e798976-add2-9e56-7283-55e6c893e3bf
# 26  7e798976-add2-9e56-7283-55e6c893e3bf
# 27  7e798976-add2-9e56-7283-55e6c893e3bf
# 28  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 29  7e798976-add2-9e56-7283-55e6c893e3bf
# 30  7e798976-add2-9e56-7283-55e6c893e3bf
# 31  7e798976-add2-9e56-7283-55e6c893e3bf
# 32  bafe0ce1-653f-1178-b41b-26d90fe5c474
# 33  39527839-3b48-fb72-2850-197248149dfd
# 34  39527839-3b48-fb72-2850-197248149dfd
# 35  39527839-3b48-fb72-2850-197248149dfd
# 36  7e798976-add2-9e56-7283-55e6c893e3bf
#
#                                 org_uuid relation_type  \
# 0   8477b533-0654-993c-b69e-be52c2ff078e       advisor
# 1   51d94123-97d9-be50-33a7-c1ee3f2bee0f     executive
# 2   352c09ba-37ee-9e0f-e729-6eb9d621adab  board_member
# 3   51d94123-97d9-be50-33a7-c1ee3f2bee0f  board_member
# 4   88b3e5d7-8c01-8428-4f86-3e816285f899     executive
# 5   00daca16-8311-454b-84e0-24a40d16be9c       advisor
# 6   b5dd7211-bdbb-3b8c-b2c5-1627f6408085     executive
# 7   87fe9937-1c68-e177-336b-b8b12797453a     executive
# 8   dfdddecb-c719-02ec-56f6-da4f071ab6e6  board_member
# 9   edcba868-67a1-5df3-5cef-5f9a455a30fc       advisor
# 10  2251d3da-7c8c-27e8-a7ae-1797af0432fe       advisor
# 11  6c4affe2-32e4-5502-3e6c-15ceb74d2529       advisor
# 12  f16869c5-e2f5-cfa8-85fa-43adffeabd1f  board_member
# 13  f5506198-5d0b-1d56-1d2c-eee2e8ae4339      investor
# 14  751f9fd0-2255-ddff-1642-3a8a2a3627cf      investor
# 15  abca185a-3c42-579f-26fb-87d0a534317c      investor
# 16  108f53d2-590c-87a3-850b-89959140740f      investor
# 17  f16869c5-e2f5-cfa8-85fa-43adffeabd1f      investor
# 18  b7df520a-4772-a30e-ddd4-78a587acd7ff      investor
# 19  48fbf67f-e2dd-a1a8-6e66-1e249c7cb71c      investor
# 20  0d39cbff-e7d3-db40-504b-0b6d6a5b46bc      investor
# 21  f6833dde-6118-5915-1a34-7627c55133b7      investor
# 22  c2c32d7a-0ec0-d5c2-d65e-fa2780ed8977      investor
# 23  0d39cbff-e7d3-db40-504b-0b6d6a5b46bc      investor
# 24  90737966-ae35-30a5-ca2d-125b94e429c9      investor
# 25  00daca16-8311-454b-84e0-24a40d16be9c      investor
# 26  b036c231-6860-7b23-ca8a-c0d88a0bb103      investor
# 27  8281b169-5e4f-79c1-dddb-594893977a54      investor
# 28  90737966-ae35-30a5-ca2d-125b94e429c9      investor
# 29  88b3e5d7-8c01-8428-4f86-3e816285f899      investor
# 30  6e73baf7-27e0-4c81-8211-ae2544d40495      investor
# 31  337115de-de1c-2cf9-b114-5b682668171c      investor
# 32  032456a4-df14-4bb0-b5a6-5793cd2bdee8      investor
# 33  0fd55f9d-a10f-44a9-a0b8-981ab5c9ab55      investor
# 34  64785d22-99d3-4e6e-87ce-d886e8418d8e      investor
# 35  64785d22-99d3-4e6e-87ce-d886e8418d8e      investor
# 36  3edbd3cc-1b0b-4ee2-a882-638d7e75b763      investor
#
#                      job_title_subsequent             org_name  \
# 0                          Senior Advisor           Videoplaza
# 1   Co-Founder & Chief Technology Officer                Wrapp
# 2                      Board of Directors          Shootitlive
# 3                            Board member                Wrapp
# 4                          Board director             Automile
# 5                                 Advisor               Antler
# 6                         CTO & Code Poet             Lookback
# 7                      Executive Chairman             Pluto TV
# 8                   Advisory Board Member             Ericsson
# 9                                 Advisor           Threadless
# 10                                Advisor        8tracks Radio
# 11                                Advisor      Recorded Future
# 12           Non-Executive Board Director           Movebubble
# 13                               investor            Tripbirds
# 14                               investor               Opbeat
# 15                               investor                 Clue
# 16                               investor          Student.com
# 17                               investor           Movebubble
# 18                               investor              Sunrise
# 19                               investor              Timekit
# 20                               investor        Triple Global
# 21                               investor                Visor
# 22                               investor               RiseML
# 23                               investor        Triple Global
# 24                               investor                Sniph
# 25                               investor               Antler
# 26                               investor             Mavenoid
# 27                               investor             Red Flag
# 28                               investor                Sniph
# 29                               investor             Automile
# 30                               investor               Aspire
# 31                               investor  Single Technologies
# 32                               investor            Coffydoor
# 33                               investor          HJN Sverige
# 34                               investor       H2 Green Steel
# 35                               investor       H2 Green Steel
# 36                               investor              Prog.AI
#
#    org_country_code       org_city  \
# 0               GBR         London
# 1               SWE      Stockholm
# 2               SWE      Stockholm
# 3               SWE      Stockholm
# 4               USA      Palo Alto
# 5               SGP      Singapore
# 6               USA     Menlo Park
# 7               USA    Los Angeles
# 8               SWE          Kista
# 9               USA        Chicago
# 10              USA  San Francisco
# 11              USA     Somerville
# 12              GBR         London
# 13              SWE      Stockholm
# 14              USA  San Francisco
# 15              DEU         Berlin
# 16              GBR         London
# 17              GBR         London
# 18              FRA          Paris
# 19              USA  San Francisco
# 20              SWE      Stockholm
# 21              USA     Long Beach
# 22              DEU         Berlin
# 23              SWE      Stockholm
# 24              SWE      Stockholm
# 25              SGP      Singapore
# 26              SWE      Stockholm
# 27              GBR         London
# 28              SWE      Stockholm
# 29              USA      Palo Alto
# 30              SGP      Singapore
# 31              SWE      Stockholm
# 32              SWE      Stockholm
# 33              SWE      Stockholm
# 34              SWE      Stockholm
# 35              SWE      Stockholm
# 36              USA  San Francisco
#
#                                                                                                                              short_description  \
# 0   Our mission is to empower broadcasters & video publishers to build profitable and sustainable businesses in the internet-delivered TV worl
# 1                                                                      Wrapp is The New Standard for rewarding purchases and customer loyalty.
# 2                                   Shootitlive designs and delivers a live publishing platform for publishers and professional photographers.
# 3                                                                      Wrapp is The New Standard for rewarding purchases and customer loyalty.
# 4                                                                   Automile offers frictionless tracking and management of fleets and assets.
# 5                                                 Antler is the investor backing the world's most driven founders, from day zero to greatness.
# 6                                                                           Lookback is a platform for easy-to-use software testing solutions.
# 7                                                                        Pluto TV is the leading free streaming television service in America.
# 8                                               Ericsson is an information and communications technology company that offers network services.
# 9       Threadless is a global community-driven design platform featuring designs created by various designers, artists and general consumers.
# 10                    8tracks is an internet radio and social network that streams user-curated song playlists that contain at least 8 tracks.
# 11                                                            Recorded Future develops a single intelligence platform for enterprise security.
# 12                                                                                  Movebubble is a property rental app in London & Manchester
# 13   Tripbirds is a travel site providing hotel listings by integrating with Facebook and Instagram and enabling travelers book hotels online.
# 14           Opbeat is an open source application performance monitoring that identifies performance issues with a breakdown that makes sense.
# 15                                                                       Clue is a female health application for period and fertility tracking
# 16                                    Student.com is a marketplace for international student housing, helping students find their home abroad.
# 17                                                                                  Movebubble is a property rental app in London & Manchester
# 18               Sunrise is a free calendar app specifically designed to make your life easier. Available on Android, iPhone, iPad, Mac & Web.
# 19                     Timekit empowers developers and designers through a set of unified APIs that deliver the entire booking infrastructure.
# 20                                               Triple is a marketplace for social traveling where anyone can host experiences for travelers.
# 21                                                                                                                 Tax advisory for the masses
# 22                                            RiseML creates software to help machine learning teams scale their deep learning infrastructure.
# 23                                               Triple is a marketplace for social traveling where anyone can host experiences for travelers.
# 24                                              Sniph is a smart subscription service for perfume, which makes it easy to discover new scents.
# 25                                                Antler is the investor backing the world's most driven founders, from day zero to greatness.
# 26                                         Mavenoid develops an AI-driven product support and troubleshooting platform for hardware companies.
# 27                                                       Red Flag develops an automated accounting, expenses, and invoicing platform for SMEs.
# 28                                              Sniph is a smart subscription service for perfume, which makes it easy to discover new scents.
# 29                                                                  Automile offers frictionless tracking and management of fleets and assets.
# 30                                                         Aspire is a financial platform providing earnings, payment, and expense management.
# 31                                                     SINGLE TECHNOLOGIES develops a new type of (3-D) DNA sequencing system to improve Life.
# 32                       Coffydoor is a subscription service that delivers premium coffee capsules at a fair price, directly to your doorstep.
# 33                      HJN Sverige is a technology business based in Sweden that specializes in machine learning and artificial intelligence.
# 34                H2 Green Steel operates a steel production plant to accelerate the decarbonization of the steel industry using green energy.
# 35                H2 Green Steel operates a steel production plant to accelerate the decarbonization of the steel industry using green energy.
# 36  Prog.AI helps to find developers on technical proficiency, libraries they have used, even contributions they have made to GitHub projects.
#
#                                                                                      category_list  \
# 0                                                                     Advertising,Publishing,Video
# 1                                                       Apps,FinTech,Gift Card,Mobile,Social Media
# 2                                                             Business Development,News,Publishing
# 3                                                       Apps,FinTech,Gift Card,Mobile,Social Media
# 4                                                      Automotive,B2B,Developer APIs,SaaS,Software
# 5                                                       Finance,Financial Services,Venture Capital
# 6                                                         Mobile,Product Design,Software,UX Design
# 7                                      Apps,Internet,Media and Entertainment,Video,Video Streaming
# 8                                        Information Technology,Internet,Mobile,Telecommunications
# 9                                              Communities,Crowdsourcing,E-Commerce,Product Design
# 10                                                    Internet Radio,Media and Entertainment,Music
# 11                                          Analytics,Cyber Security,Intelligent Systems,Real Time
# 12                                                                     Apps,Internet,Mobile,Rental
# 13                               Information Services,Information Technology,Social Network,Travel
# 14                                                          Computer,Internet,Open Source,Software
# 15                                             Apps,Fertility,Health Care,mHealth,Wellness,Women's
# 16                                                                          Consulting,Marketplace
# 17                                                                     Apps,Internet,Mobile,Rental
# 18                                                               Apps,Email,Events,Internet,Mobile
# 19                                                                  Developer APIs,Mobile,Software
# 20                                                            Leisure,Marketing,Marketplace,Travel
# 21                                                                      Financial Services,FinTech
# 22                                 Artificial Intelligence (AI),Internet,Machine Learning,Software
# 23                                                            Leisure,Marketing,Marketplace,Travel
# 24                                                                        Beauty,Fashion,Lifestyle
# 25                                                      Finance,Financial Services,Venture Capital
# 26  Artificial Intelligence (AI),Customer Service,Hardware,Industrial Automation,Technical Support
# 27                                                                 Accounting,Credit,Payments,SaaS
# 28                                                                        Beauty,Fashion,Lifestyle
# 29                                                     Automotive,B2B,Developer APIs,SaaS,Software
# 30                                  Banking,Financial Services,FinTech,Small and Medium Businesses
# 31                                           Biotechnology,Genetics,Health Care,Health Diagnostics
# 32                                                                        Coffee,Food and Beverage
# 33                   Artificial Intelligence (AI),Information Technology,Machine Learning,Software
# 34                                                    CleanTech,GreenTech,Industrial Manufacturing
# 35                                                    CleanTech,GreenTech,Industrial Manufacturing
# 36                              Developer Platform,Email Marketing,Information Services,Recruiting
#
#     total_funding_usd founded_on  \
# 0        1.742782e+07 2007-11-01
# 1        3.754012e+07 2011-05-01
# 2        3.111380e+05 2008-05-05
# 3        3.754012e+07 2011-05-01
# 4        4.730613e+07 2013-01-01
# 5        8.220000e+07 2017-01-01
# 6        8.200000e+06 2013-01-01
# 7        5.180000e+07 2013-01-01
# 8        1.589787e+09 1876-01-01
# 9        0.000000e+00 2000-11-01
# 10       8.989857e+06 2008-08-08
# 11       6.922596e+07 2009-01-01
# 12       4.218114e+06 2013-01-01
# 13       7.400000e+05 2011-06-01
# 14       2.800000e+06 2012-01-01
# 15       6.471121e+07 2012-01-01
# 16       8.000000e+07 2011-01-01
# 17       4.218114e+06 2013-01-01
# 18       1.029596e+07 2012-12-01
# 19       1.700000e+06 2015-01-01
# 20       1.060652e+06 2016-10-01
# 21       1.550000e+07 2016-01-01
# 22       9.106000e+05 2016-09-01
# 23       1.060652e+06 2016-10-01
# 24       1.778362e+06 2015-01-01
# 25       8.220000e+07 2017-01-01
# 26       3.990000e+07 2017-01-01
# 27       7.891927e+06 2016-01-01
# 28       1.778362e+06 2015-01-01
# 29       4.730613e+07 2013-01-01
# 30       2.995000e+08 2018-01-01
# 31       9.246416e+06 2013-01-01
# 32       0.000000e+00 2020-01-01
# 33       1.930000e+06 2018-01-01
# 34       1.091596e+10 2020-01-01
# 35       1.091596e+10 2020-01-01
# 36       1.000000e+06 2022-03-01
#
#                                                                                                          org_logo_url  \
# 0   https://images.crunchbase.com/image/upload/t_cb-default-original/v1397189977/ce8229a5e9e6f065e84bf41437f2fa87.png
# 1                               https://images.crunchbase.com/image/upload/t_cb-default-original/s4t0zdisweychs5tfxfy
# 2   https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180596/33c4c79dd70482e40aecadb6beb0562c.png
# 3                               https://images.crunchbase.com/image/upload/t_cb-default-original/s4t0zdisweychs5tfxfy
# 4               https://images.crunchbase.com/image/upload/t_cb-default-original/v1482521626/jakzy9ivmegl8o7sroed.png
# 5                               https://images.crunchbase.com/image/upload/t_cb-default-original/c7spuuktidov5ckclnoy
# 6               https://images.crunchbase.com/image/upload/t_cb-default-original/v1426358818/u8ejo6w7vvi5ectctfjf.png
# 7                               https://images.crunchbase.com/image/upload/t_cb-default-original/ecdphkz2zo8b7xr8usq4
# 8                               https://images.crunchbase.com/image/upload/t_cb-default-original/cmazrdxlkfgyxjax4p3x
# 9   https://images.crunchbase.com/image/upload/t_cb-default-original/v1397182106/2e87adfa6083a78dab4955b3f032672d.png
# 10  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397195325/8a34e592d7cae593ad6be7b61087f699.png
# 11                              https://images.crunchbase.com/image/upload/t_cb-default-original/ktnj3i4jfhgll9perlnr
# 12                              https://images.crunchbase.com/image/upload/t_cb-default-original/u14fyp9bxljfiapxmmnw
# 13  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180437/86eac0fefbf4d659dc4bfdaf5c844276.jpg
# 14                              https://images.crunchbase.com/image/upload/t_cb-default-original/fddgdptrebo9ve6keq6b
# 15  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397180759/d479cbca0b9b6d20b9d58be75e58f801.png
# 16              https://images.crunchbase.com/image/upload/t_cb-default-original/v1444834430/kkwurcm0qfjarpyrkbh4.jpg
# 17                              https://images.crunchbase.com/image/upload/t_cb-default-original/u14fyp9bxljfiapxmmnw
# 18  https://images.crunchbase.com/image/upload/t_cb-default-original/v1397187893/933eeffebf13e218faeff0e90e68d15f.png
# 19              https://images.crunchbase.com/image/upload/t_cb-default-original/v1484676531/abooje82p63ukrwgkg4t.png
# 20              https://images.crunchbase.com/image/upload/t_cb-default-original/v1505970694/dxbyrihzm6t5rqoatepr.jpg
# 21                              https://images.crunchbase.com/image/upload/t_cb-default-original/srlnpw7ipfjvl12alkxe
# 22                              https://images.crunchbase.com/image/upload/t_cb-default-original/gicxkrqdxi6y0ctlrn6z
# 23              https://images.crunchbase.com/image/upload/t_cb-default-original/v1505970694/dxbyrihzm6t5rqoatepr.jpg
# 24              https://images.crunchbase.com/image/upload/t_cb-default-original/v1459252193/bum3bae7jsxlg5jlwdfn.jpg
# 25                              https://images.crunchbase.com/image/upload/t_cb-default-original/c7spuuktidov5ckclnoy
# 26                              https://images.crunchbase.com/image/upload/t_cb-default-original/ai8n6mffccs8wx4jpup7
# 27              https://images.crunchbase.com/image/upload/t_cb-default-original/v1489666894/jldataa4avrid2ikyzlf.png
# 28              https://images.crunchbase.com/image/upload/t_cb-default-original/v1459252193/bum3bae7jsxlg5jlwdfn.jpg
# 29              https://images.crunchbase.com/image/upload/t_cb-default-original/v1482521626/jakzy9ivmegl8o7sroed.png
# 30                              https://images.crunchbase.com/image/upload/t_cb-default-original/elkxxs4m1q0w660kc5af
# 31              https://images.crunchbase.com/image/upload/t_cb-default-original/v1456721192/y5gwbkz49rz9fpzxs9ns.png
# 32                              https://images.crunchbase.com/image/upload/t_cb-default-original/lp442kynz1dwrkitphuo
# 33                                                                                                                NaN
# 34                              https://images.crunchbase.com/image/upload/t_cb-default-original/gkg0q7zvupqpfjsgxoua
# 35                              https://images.crunchbase.com/image/upload/t_cb-default-original/gkg0q7zvupqpfjsgxoua
# 36                              https://images.crunchbase.com/image/upload/t_cb-default-original/wsr2auvypek7xetlzdkz
#
#                            acquirer_uuid    exit_type  \
# 0   55272742-9158-69f1-31a1-364322caff54  acquisition
# 1   158ee541-b480-1407-83c3-d28ff03babc4  acquisition
# 2   dc6f66bd-0521-ab5d-dd2b-e60aca283151  acquisition
# 3   158ee541-b480-1407-83c3-d28ff03babc4  acquisition
# 4                                    NaN          NaN
# 5                                    NaN          NaN
# 6                                    NaN          NaN
# 7   4522b60d-0b04-827e-2b6c-6eaf236cf636  acquisition
# 8   8b794550-2ad2-4a1a-9317-b71898187d27  acquisition
# 9                                    NaN          NaN
# 10                                   NaN          NaN
# 11  6efb9171-a87b-212d-f399-b0613da7b1c9  acquisition
# 12                                   NaN          NaN
# 13                                   NaN          NaN
# 14  e0d34498-56d2-ff04-5ff1-4775d10fcc09  acquisition
# 15                                   NaN          NaN
# 16                                   NaN          NaN
# 17                                   NaN          NaN
# 18  fd80725f-53fc-7009-9878-aeecf1e9ffbb  acquisition
# 19  eb7cef2b-ff40-c0e8-38c2-c6a2988389df  acquisition
# 20                                   NaN          NaN
# 21                                   NaN          NaN
# 22                                   NaN          NaN
# 23                                   NaN          NaN
# 24                                   NaN          NaN
# 25                                   NaN          NaN
# 26                                   NaN          NaN
# 27  6d942ddd-5fe8-23fe-093d-d054a5ceca1a  acquisition
# 28                                   NaN          NaN
# 29                                   NaN          NaN
# 30                                   NaN          NaN
# 31                                   NaN          NaN
# 32                                   NaN          NaN
# 33                                   NaN          NaN
# 34                                   NaN          NaN
# 35                                   NaN          NaN
# 36                                   NaN          NaN
#
#                                      acquirer_name  exit_date  \
# 0                                            Dalet 2014-10-20
# 1                                           Meniga 2019-01-10
# 2                                TT Nyhetsbyran AB 2016-09-30
# 3                                           Meniga 2019-01-10
# 4                                              NaN        NaT
# 5                                              NaN        NaT
# 6                                              NaN        NaT
# 7   VIACOM PARAMOUNT on contract at CBS PARAMOUNT+ 2019-01-22
# 8                                          Bizitek 2009-06-01
# 9                                              NaN        NaT
# 10                                             NaN        NaT
# 11                                Insight Partners 2019-05-30
# 12                                             NaN        NaT
# 13                                             NaN        NaT
# 14                                         Elastic 2017-06-22
# 15                                             NaN        NaT
# 16                                             NaN        NaT
# 17                                             NaN        NaT
# 18                                       Microsoft 2015-02-04
# 19                                    Tulip Retail 2020-11-24
# 20                                             NaN        NaT
# 21                                             NaN        NaT
# 22                                             NaN        NaT
# 23                                             NaN        NaT
# 24                                             NaN        NaT
# 25                                             NaN        NaT
# 26                                             NaN        NaT
# 27                                           Bokio 2020-04-21
# 28                                             NaN        NaT
# 29                                             NaN        NaT
# 30                                             NaN        NaT
# 31                                             NaN        NaT
# 32                                             NaN        NaT
# 33                                             NaN        NaT
# 34                                             NaN        NaT
# 35                                             NaN        NaT
# 36                                             NaN        NaT
#
#    acquisition_type  exit_valuation
# 0       acquisition             NaN
# 1       acquisition             NaN
# 2       acquisition             NaN
# 3       acquisition             NaN
# 4               NaN             NaN
# 5               NaN             NaN
# 6               NaN             NaN
# 7       acquisition     340000000.0
# 8               NaN             NaN
# 9               NaN             NaN
# 10              NaN             NaN
# 11      acquisition     780000000.0
# 12              NaN             NaN
# 13              NaN             NaN
# 14      acquisition             NaN
# 15              NaN             NaN
# 16              NaN             NaN
# 17              NaN             NaN
# 18      acquisition     100000000.0
# 19      acquisition             NaN
# 20              NaN             NaN
# 21              NaN             NaN
# 22              NaN             NaN
# 23              NaN             NaN
# 24              NaN             NaN
# 25              NaN             NaN
# 26              NaN             NaN
# 27            merge             NaN
# 28              NaN             NaN
# 29              NaN             NaN
# 30              NaN             NaN
# 31              NaN             NaN
# 32              NaN             NaN
# 33              NaN             NaN
# 34              NaN             NaN
# 35              NaN             NaN
# 36              NaN             NaN

# %%
subsequent_orgs_info = (
    subsequent_orgs_info
    .drop_duplicates(subset = ['org_uuid'])
)[['org_uuid', 'org_name', 'org_country_code', 'org_city', 'short_description', 'category_list', 'total_funding_usd', 'founded_on', 'org_logo_url', 'exit_type', 'exit_date', 'exit_valuation', 'acquirer_uuid', 'acquirer_name', 'acquisition_type']]

# %%
export_df = subsequent_orgs_info.rename(columns={
    'org_uuid': 'orgUuid',
    'org_name': 'orgName',
    'org_country_code': 'orgCountryCode',
    'org_city': 'orgCity',
    'short_description': 'shortDescription',
    'category_list': 'categoryList',
    'total_funding_usd': 'totalFundingUsd',
    'founded_on': 'foundedOn',
    'org_logo_url': 'orgLogoUrl',
    'exit_type': 'exitType',
    'exit_date': 'exitDate',
    'exit_valuation': 'exitValuation',
    'acquirer_uuid': 'acquirerUuid',
    'acquirer_name': 'acquirerName',
    'acquisition_type': 'acquisitionType',
}).drop(columns = ['categoryList'], axis = 1)

export_df.to_json('data/output/subsequentOrgsInfo_' + target_org_uuid + '.json', orient = 'records')
